    "lat": 35.58016014789423
  },
  {
    "lng": -83.6245224473222,
    "lat": 35.57760025411335
  },
  {
    "lng": -83.61867570284112,
    "lat": 35.577952645524405
  },
  {
    "lng": -83.61504668902526,
    "lat": 35.57927702437538
  },
  {
    "lng": -83.60960316830148,
    "lat": 35.58042490109351
  },
  {
    "lng": -83.60365561788105,
    "lat": 35.58263056489945
  },
  {
    "lng": -83.60053063376185,
    "lat": 35.583866692684
  },
  {
    "lng": -83.59730484370331,
    "lat": 35.58466033942718
  },
  {
    "lng": -83.58571216068046,
    "lat": 35.59198517794028
  },
  {
    "lng": -83.58490571316581,
    "lat": 35.592426433272394
  },
  {
    "lng": -83.58127599930872,
    "lat": 35.59233818220597
  },
  {
    "lng": -83.57482511923288,
    "lat": 35.58889577776085
  },
  {
    "lng": -83.57321222420362,
    "lat": 35.58730848427449
  }
]

# %%
@run(once=True)
def cache():
    path = auto.pathlib.Path.cwd() / 'tmp' / 'elevation.shelve'
    return auto.shelve.open(str(path), 'c')

# %%
@run
def fetch(cache, /):
    def fetch(url: str, *, tqdm=None) -> bytes:
        key = url
        if key not in cache:
            if tqdm is not None:
                tqdm.set_description(f'Cache Miss: {url}')

            with auto.requests.get(url) as r:
                r.raise_for_status()
                cache[key] = r.content
            
            auto.time.sleep(1)
        
        else:
            if tqdm is not None:
                tqdm.set_description(f'Cache Hit: {url}')
        
        return cache[key]

    return fetch

# %%
import requests
import json

session = requests.Session()

class Coordinate:
    lat: int
    lng: int
    alt: int


@run
def elevation(fetch, /):
    new_coordinates = []
    for coord in coords:
        url = f'https://api.open-meteo.com/v1/elevation?latitude={coord["lat"]}&longitude={coord["lng"]}'
        alt = auto.json.loads(fetch(url))['elevation'][0]
        new_coordinates.append(
            {
                "lat": coord["lat"],
                "lng": coord["lng"],
                "alt": alt,
            }
        )

    # Print the new coordinate
    for coord in new_coordinates:
        print(coord)

    # Write the coordinate to a file
    with open("park.json", "w") as file:
        json.dump(new_coordinates, file, indent=4)
# Out:
# {'lat': 35.33788032783195, 'lng': -84.02952010915494, 'alt': 1326.0}
# {'lat': 35.342851191719134, 'lng': -84.02502444427735, 'alt': 1384.0}
# {'lat': 35.346116481176786, 'lng': -84.02240278981355, 'alt': 1265.0}
# {'lat': 35.34920588135622, 'lng': -84.01998414731091, 'alt': 1310.0}
# {'lat': 35.35432444320874, 'lng': -84.01685916319168, 'alt': 1358.0}
# {'lat': 35.35697197520143, 'lng': -84.0144398206478, 'alt': 1325.0}
# {'lat': 35.359620120048746, 'lng': -84.0139861939208, 'alt': 1347.0}
# {'lat': 35.36412031158169, 'lng': -84.01312934343652, 'alt': 1408.0}
# {'lat': 35.370297886231285, 'lng': -84.01423820876911, 'alt': 1457.0}
# {'lat': 35.37391679280926, 'lng': -84.01544717999984, 'alt': 1302.0}
# {'lat': 35.37541644808382, 'lng': -84.0144398206478, 'alt': 1331.0}
# {'lat': 35.3794766099939, 'lng': -84.01413670278855, 'alt': 1237.0}
# {'lat': 35.381065129189516, 'lng': -84.01700967205944, 'alt': 1193.0}
# {'lat': 35.38777159738303, 'lng': -84.01973213246258, 'alt': 1106.0}
# ...
