# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Start" data-toc-modified-id="Start-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Start</a></span></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Date-(year,-month,-day)-to-location-(lat,-lng)" data-toc-modified-id="Date-(year,-month,-day)-to-location-(lat,-lng)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Date (year, month, day) to location (lat, lng)</a></span></li><li><span><a href="#Location-(lat,-lng,-alt)-to-spatial-(x,-y,-z)" data-toc-modified-id="Location-(lat,-lng,-alt)-to-spatial-(x,-y,-z)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Location (lat, lng, alt) to spatial (x, y, z)</a></span></li><li><span><a href="#Tile-(zoom,-x,-y)-to-location-(lat,-lng)" data-toc-modified-id="Tile-(zoom,-x,-y)-to-location-(lat,-lng)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Tile (zoom, x, y) to location (lat, lng)</a></span></li></ul></li><li><span><a href="#Initialize-&amp;-Load-Data" data-toc-modified-id="Initialize-&amp;-Load-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Initialize &amp; Load Data</a></span></li><li><span><a href="#OSPRay" data-toc-modified-id="OSPRay-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>OSPRay</a></span><ul class="toc-item"><li><span><a href="#Config" data-toc-modified-id="Config-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Config</a></span></li><li><span><a href="#Download" data-toc-modified-id="Download-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Download</a></span></li><li><span><a href="#Extract" data-toc-modified-id="Extract-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Extract</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Definitions" data-toc-modified-id="Definitions-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Definitions</a></span></li></ul></li><li><span><a href="#Render" data-toc-modified-id="Render-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Render</a></span><ul class="toc-item"><li><span><a href="#Terrain-(OSPGeometry)" data-toc-modified-id="Terrain-(OSPGeometry)-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Terrain (OSPGeometry)</a></span></li><li><span><a href="#Colormap-(OSPMaterial[])" data-toc-modified-id="Colormap-(OSPMaterial[])-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Colormap (OSPMaterial[])</a></span></li><li><span><a href="#Observation-(uint[8])" data-toc-modified-id="Observation-(uint[8])-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Observation (uint[8])</a></span></li><li><span><a href="#OSPWorld" data-toc-modified-id="OSPWorld-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>OSPWorld</a></span></li><li><span><a href="#OSPCamera" data-toc-modified-id="OSPCamera-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>OSPCamera</a></span></li><li><span><a href="#OSPRenderer" data-toc-modified-id="OSPRenderer-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>OSPRenderer</a></span></li><li><span><a href="#Load-Trail" data-toc-modified-id="Load-Trail-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Load Trail</a></span></li><li><span><a href="#Render-Single" data-toc-modified-id="Render-Single-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Render Single</a></span></li></ul></li><li><span><a href="#Video" data-toc-modified-id="Video-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Video</a></span><ul class="toc-item"><li><span><a href="#Animation-Widget" data-toc-modified-id="Animation-Widget-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Animation Widget</a></span></li><li><span><a href="#ffmpeg" data-toc-modified-id="ffmpeg-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>ffmpeg</a></span></li><li><span><a href="#render()" data-toc-modified-id="render()-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span><code>render()</code></a></span></li><li><span><a href="#Animate" data-toc-modified-id="Animate-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Animate</a></span></li></ul></li><li><span><a href="#Figure-out-OSPRay-equirectangular-coordinates" data-toc-modified-id="Figure-out-OSPRay-equirectangular-coordinates-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Figure out OSPRay equirectangular coordinates</a></span></li><li><span><a href="#Sunrise-as-a-Service" data-toc-modified-id="Sunrise-as-a-Service-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Sunrise-as-a-Service</a></span><ul class="toc-item"><li><span><a href="#Inputs" data-toc-modified-id="Inputs-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Inputs</a></span></li><li><span><a href="#patchbay.pub" data-toc-modified-id="patchbay.pub-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span><code>patchbay.pub</code></a></span></li><li><span><a href="#index.html" data-toc-modified-id="index.html-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span><code>index.html</code></a></span></li><li><span><a href="#Run-Server" data-toc-modified-id="Run-Server-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Run Server</a></span></li></ul></li><li><span><a href="#End" data-toc-modified-id="End-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>End</a></span></li></ul></div>

# %% [markdown]
# # Start

# %%
# !hostname
# !date
# %cd ~/src/Sunrise-Demo/
from __future__ import annotations
try:
    from mediocreatbest import auto, run
except ImportError:
    # %pip install --quiet --upgrade pip
    # %pip install --upgrade --force-reinstall \
        mediocreatbest@git+https://gist.github.com/player1537/3457b026ed6ef6696d758517f55a58df.git
    from mediocreatbest import auto, run
# Out:
# accona
# Fri Jan 12 09:52:35 PM UTC 2024
# /home/raustin9/src/Sunrise-Demo
# /home/raustin9/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
DO_SAVE = True
TERRAIN_QUALITY = (
    0
#     1
#     2
)
VIDEO_QUALITY = (
#     0
#     1
    2
)

# %% [markdown]
# # Setup

# %% [markdown]
# ## Date (year, month, day) to location (lat, lng)

# %%
# %%scope -o convert_date_to_sun_location
# auto.skyfield; import skyfield.api
#
# planets = auto.skyfield.api.load('de421.bsp')
# sun = planets['sun']
# earth = planets['earth']
#
# ts = auto.skyfield.api.load.timescale()
#
# def convert_date_to_sun_location(
#     now: auto.datetime.datetime,
#     /,
# ) -> tuple[Degree, Degree]:
#     t = ts.from_datetime(now)
#
#     position = earth.at(t).observe(sun).apparent()
#
#     location = auto.skyfield.toposlib.wgs84.geographic_position_of(position)
#     latitude = location.latitude.degrees
#     longitude = location.longitude.degrees
#
#     return latitude, longitude
#
# goal: 'seconds' = 10
# rate: '1/seconds' = 130.0
# N = int(goal * rate)
#
# keys = ['latitude', 'longitude']
# K = len(keys)
#
# X = auto.numpy.linspace(0.0, 90.0, num=N)
# Y = auto.numpy.zeros(
#     shape=(N, K),
#     dtype='f4',
# )
#
# ref = auto.datetime.datetime(year=2023, month=1, day=1, tzinfo=auto.datetime.timezone.utc)
#
# for n, x in enumerate(auto.tqdm.tqdm(X)):
#     values = convert_date_to_sun_location(ref + auto.datetime.timedelta(days=x))
#     for k in range(K):
#         Y[n, k] = values[k]
#
# %matplotlib inline
# fig = auto.matplotlib.pyplot.figure()
#
# for k, key in enumerate(keys):
#     ax = fig.add_subplot(K, 1, k+1)
#     ax.plot(X, Y[:, k], label=f'{key}')
#     ax.legend()
#
# fig.tight_layout()
# fig.show()
# Out:
# 100%|██████████| 1300/1300 [00:09<00:00, 130.32it/s]

# %% [markdown]
# ## Location (lat, lng, alt) to spatial (x, y, z)

# %%
def convert_location_to_spatial(
    *,
    lat: Degree,
    lng: Degree,
    alt: Meter,
    math=auto.math,
) -> Tuple[Meter, Meter, Meter]:
    # Thanks https://gis.stackexchange.com/a/4148
    
    #> Note that "Lat/Lon/Alt" is just another name for spherical coordinates, and 
    #> phi/theta/rho are just another name for latitude, longitude, and altitude.
    #> :) (A minor difference: altitude is usually measured from the surface of the 
    #> sphere; rho is measured from the center -- to convert, just add/subtract the 
    #> radius of the sphere.)
    phi: Radian = math.radians(lat)
    theta: Radian = math.radians(lng)
    
    # Thanks https://en.wikipedia.org/wiki/Earth_radius
    #> A globally-average value is usually considered to be 6,371 kilometres (3,959 mi)
    rho: Meter = 6_371_000 + alt
    
    #> x = math.cos(phi) * math.cos(theta) * rho
    x: Meter = math.cos(phi) * math.cos(theta) * rho
    
    #> y = math.cos(phi) * math.sin(theta) * rho
    y: Meter = math.cos(phi) * math.sin(theta) * rho

    #> z = math.sin(phi) * rho # z is 'up'
    z: Meter = math.sin(phi) * rho
    
    #> (Note there's some slightly arbitrary choices here in what each axis means...
    #> you might want 'y' to point at the north pole instead of 'z', for example.)
    
    # I do :)
    y, z = z, y
    
    return x, y, z

# %% [markdown]
# ## Tile (zoom, x, y) to location (lat, lng)

# %%
@auto.mediocreatbest.doctest
def convert_tile_coordinates_to_latlng(
    *,
    z: int,
    x: int,
    y: int,
    math=auto.numpy,
    return_google_maps_url: bool=False,
) -> Tuple[Degree, Degree]:
    r"""

    >>> convert_tile_coordinates_to_latlng(z=15, x=8739, y=12925, return_google_maps_url=True)
    'https://www.google.com/maps/@35.48751102385376,-83.990478515625,15.79z?entry=ttu'

    """
    
    # Thanks https://gis.stackexchange.com/a/133535
    
    #> n = 2 ^ zoom
    n = 2 ** z
    
    #> lon_deg = xtile / n * 360.0 - 180.0
    lon_deg = x / n * 360.0 - 180.0
    
    #> lat_rad = arctan(sinh(π * (1 - 2 * ytile / n)))
    lat_rad = math.arctan(math.sinh(math.pi * (1.0 - 2.0 * y / n)))
    
    #> lat_deg = lat_rad * 180.0 / π
    lat_deg = lat_rad * 180.0 / math.pi
    
    if return_google_maps_url:
        return f"""https://www.google.com/maps/@{lat_deg},{lon_deg},15.79z?entry=ttu"""
    
    return lat_deg, lon_deg

# %%
# %%scope -o Tixel
#
# @auto.dataclasses.dataclass(eq=True, order=True, frozen=True)
# class Tixel:
#     y: int
#     x: int
#
#     z: ClassVar[int] = 23
#
#     @property
#     def location(self) -> Location:
#         """Center lat/lng of current tixel"""
#         lat, lng = tile_coordinates_to_latlng(
#             z=1+self.z,
#             x=1+self.x,
#             y=1+self.y,
#         )
#         return Location(lat=lat, lng=lng)
#
# # @Tixel.register
# # def __tixel_from_coord(coord: Coord, /, *, res: int):
# #     dz = int(auto.math.log2(Tixel.z - coord.z))

# %% [markdown]
# # Initialize & Load Data

# %%
@run
def interpolate():
    def load(
        *,
        name: str,
        method: str,
    ) -> auto.scipy.interpolate.RegularGridInterpolator:
        path = auto.pathlib.Path.cwd() / 'tmp' / f'{name}.npz'
        assert path.exists(), \
            f"""{path=!r}"""
        print(f"""Reading {path.stat().st_size :,d} bytes from {path}""")
        
        with auto.numpy.load(path) as f:
            points0 = f['points0']
            points1 = f['points1']
            values = f['values']
        
        print(f"""  Interpolation ranges from:
    {points0.shape} tixel rows
    {points1.shape} tixel columns""")
        
        return auto.scipy.interpolate.RegularGridInterpolator(
            points=(
                points0,
                points1,
            ),
            values=values,
            method=method,
        )

    elevation = load(
        name='elevation',
        method='linear',
    )
    
    observation = load(
        name='observation',
        method='nearest',
    )
    
    background = load(
        name='background',
        method='nearest',
    )
    
    return auto.mediocreatbest.namedtuple.elevation.observation.background(
        elevation,
        observation,
        background,
    )
# Out:
# Reading 28,181,785 bytes from /home/raustin9/src/Sunrise-Demo/tmp/elevation.npz
#   Interpolation ranges from:
#     (3072,) tixel rows
#     (4096,) tixel columns
# Reading 8,605,747 bytes from /home/raustin9/src/Sunrise-Demo/tmp/observation.npz
#   Interpolation ranges from:
#     (10496,) tixel rows
#     (22528,) tixel columns
# Reading 4,640,747 bytes from /home/raustin9/src/Sunrise-Demo/tmp/background.npz
#   Interpolation ranges from:
#     (2048,) tixel rows
#     (3072,) tixel columns

# %% [markdown]
# # OSPRay

# %% [markdown]
# ## Config

# %%
@run(scope='ospray')
def version():
    return (
        '2.12.0'
    )

# %% [markdown]
# ## Download

# %%
@run(scope='ospray')
def tarball(version, /) -> auto.pathlib.Path:
    # Thanks https://stackoverflow.com/a/44378512
    #> from urllib.request import urlretrieve

    #> url = 'http://mirror.pnl.gov/releases/16.04.2/ubuntu-16.04.2-desktop-amd64.iso'
    src = f"""https://github.com/ospray/ospray/releases/download/v{version}/ospray-{version}.x86_64.linux.tar.gz"""
    
    #> dst = 'ubuntu-16.04.2-desktop-amd64.iso'
    dst = auto.pathlib.Path.cwd() / 'tmp' / f"""ospray-{version}.tar.gz"""
    
    #> urlretrieve(url, dst)
    if not dst.exists():
        print(f"""Download {src} to {dst}""")
        auto.urllib.request.urlretrieve(src, str(dst))
    
    else:
        print(f"""Already downloaded to {dst}""")
    
    return dst
# Out:
# Already downloaded to /home/raustin9/src/Sunrise-Demo/tmp/ospray-2.12.0.tar.gz

# %% [markdown]
# ## Extract

# %%
@run(scope='ospray')
def prefix(version, tarball: Path, /) -> auto.pathlib.Path:
    src = tarball
    dst = auto.pathlib.Path.cwd() / 'tmp' / f"""ospray-{version}"""
    
    if dst.exists():
        print(f"""Already extracted {src} to {dst}""")
    
    else:
        with auto.tempfile.TemporaryDirectory() as tmp:
            print(f"""Extract {src} to {tmp}""")
            tmp = auto.pathlib.Path(tmp)
            
            with auto.tarfile.open(src, 'r') as tar:
                tar.extractall(tmp)

            src = tmp / f"""ospray-{version}.x86_64.linux"""
            print(f"""Move {src} to {dst}""")
            auto.shutil.move(src, dst)
    
    return dst
# Out:
# Already extracted /home/raustin9/src/Sunrise-Demo/tmp/ospray-2.12.0.tar.gz to /home/raustin9/src/Sunrise-Demo/tmp/ospray-2.12.0

# %% [markdown]
# ## Load

# %%
@run(scope='ospray', once=True)
def lib(prefix: Path, /):
    return auto.ctypes.CDLL(
        name=(
            prefix / 'lib' / 'libospray.so'
        ),
        mode=auto.os.RTLD_LOCAL | auto.os.RTLD_DEEPBIND,
    )

# %% [markdown]
# ## Init

# %%
@run(scope='ospray', once=True)
def __init(lib, /):
    lib.ospInit.argtypes = [
        auto.ctypes.POINTER(auto.ctypes.c_int),
        auto.ctypes.POINTER(auto.ctypes.c_char_p),
    ]
    lib.ospInit.restype = auto.ctypes.c_uint32
    
    error = lib.ospInit(None, None)
    assert error == 0, \
        f"""Error during ospInit: {error=!r}"""

# %% [markdown]
# ## Definitions

# %%
@run(scope='ospray')
def __definitions(lib, /):
    if not hasattr(lib, 'OSPObject'):
        lib.OSPObject = auto.ctypes.POINTER(type('OSPObject', (auto.ctypes.Structure,), {
            '_fields': [],
        }))
    
    for name in auto.re.findall(r'\w+', r'''
        *OSPCamera, *OSPData, OSPFrameBuffer, *OSPFuture, *OSPGeometricModel,
        **OSPGeometry, *OSPGroup, OSPImageOperation, *OSPInstance, *OSPLight,
        **OSPMaterial, *, OSPRenderer, *OSPTexture,
        **OSPTransferFunction, *OSPVolume, OSPVolumetricModel, *OSPWorld;
    '''):
#         setattr(lib, name, auto.ctypes.POINTER(type(name, (OSPObject,), {
#             '_fields_': [],
#         })))
        setattr(lib, name, lib.OSPObject)
    
    lib.OSPError = type('OSPError', (auto.ctypes.c_uint32,), dict(
        OSP_NO_ERROR=0,  # no error occurred
        OSP_UNKNOWN_ERROR=1,  # an unknown error occurred
        OSP_INVALID_ARGUMENT=2,  # an invalid argument was specified
        OSP_INVALID_OPERATION=3,  # the operation is not allowed for the specified object
        OSP_OUT_OF_MEMORY=4,  # there is not enough memory to execute the command
        OSP_UNSUPPORTED_CPU=5,  # the CPU is not supported (minimum ISA is SSE4.1 on x86_64 and NEON on ARM64)
        OSP_VERSION_MISMATCH=6,  # a module could not be loaded due to mismatching version
    ))
    
    lib.OSPDataType = auto.ctypes.c_uint32
    lib.OSPFrameBufferFormat = auto.ctypes.c_uint32
    lib.OSPFrameBufferChannel = auto.ctypes.c_uint32
    lib.OSPTextureFormat = auto.ctypes.c_uint32
    lib.OSPTextureFilter = auto.ctypes.c_uint32
    lib.OSPIntensityQuantity = auto.ctypes.c_char
    for name, value in dict(
        # highest bit to represent objects/handles
        OSP_OBJECT = 0x8000000,

        # object subtypes
        OSP_DATA = 0x8000000 + 100 + 0,
        OSP_CAMERA = 0x8000000 + 100 + 1,
        OSP_FRAMEBUFFER = 0x8000000 + 100 + 2,
        OSP_FUTURE = 0x8000000 + 100 + 3,
        OSP_GEOMETRIC_MODEL = 0x8000000 + 100 + 4,
        OSP_GEOMETRY = 0x8000000 + 100 + 5,
        OSP_GROUP = 0x8000000 + 100 + 6,
        OSP_IMAGE_OPERATION = 0x8000000 + 100 + 7,
        OSP_INSTANCE = 0x8000000 + 100 + 8,
        OSP_LIGHT = 0x8000000 + 100 + 9,
        OSP_MATERIAL = 0x8000000 + 100 + 10,
        OSP_RENDERER = 0x8000000 + 100 + 11,
        OSP_TEXTURE = 0x8000000 + 100 + 12,
        OSP_TRANSFER_FUNCTION = 0x8000000 + 100 + 13,
        OSP_VOLUME = 0x8000000 + 100 + 14,
        OSP_VOLUMETRIC_MODEL = 0x8000000 + 100 + 15,
        OSP_WORLD = 0x8000000 + 100 + 16,
        
        OSP_UCHAR = 2500,
        OSP_VEC2UC = 2501,
        OSP_VEC3UC = 2502,
        OSP_VEC4UC = 2503,
        
        OSP_VEC4UI = 4500 + 3,
        OSP_VEC2F = 6000 + 1,
        OSP_VEC3F = 6000 + 2,
        OSP_VEC4F = 6000 + 3,
        
        OSP_LINEAR2F = 12000 + 0,
        OSP_LINEAR3F = 12000 + 1,
        OSP_AFFINE2F = 12000 + 2,
        OSP_AFFINE3F = 12000 + 3,
        
        OSP_FB_NONE = 0,
        OSP_FB_RGBA8 = 1,
        OSP_FB_SRGBA = 2,
        OSP_FB_RGBA32F = 3,
        
        OSP_FB_COLOR = 1 << 0,
        OSP_FB_DEPTH = 1 << 1,
        OSP_FB_ACCUM = 1 << 2,
        OSP_FB_VARIANCE = 1 << 3,
        
        OSP_TEXTURE_RGBA8 = 0,
        OSP_TEXTURE_SRGBA = 1,
        OSP_TEXTURE_RGBA32F = 2,
        OSP_TEXTURE_RGB8 = 3,
        OSP_TEXTURE_SRGB = 4,
        OSP_TEXTURE_RGB32F = 5,
        OSP_TEXTURE_R8 = 6,
        OSP_TEXTURE_R32F = 7,
        OSP_TEXTURE_L8 = 8,
        OSP_TEXTURE_RA8 = 9,
        OSP_TEXTURE_LA8 = 10,
        OSP_TEXTURE_RGBA16 = 11,
        OSP_TEXTURE_RGB16 = 12,
        OSP_TEXTURE_RA16 = 13,
        OSP_TEXTURE_R16 = 14,
        
        OSP_TEXTURE_FILTER_BILINEAR = 0,
        OSP_TEXTURE_FILTER_NEAREST = 1,
        
        OSP_INTENSITY_QUANTITY_RADIANCE=0, # unit W/sr/m^2
        OSP_INTENSITY_QUANTITY_IRRADIANCE=1, # unit W/m^2
        OSP_INTENSITY_QUANTITY_INTENSITY=2, # radiant intensity, unit W/sr
        OSP_INTENSITY_QUANTITY_POWER=3, # radiant flux, unit W
        OSP_INTENSITY_QUANTITY_SCALE=4, # linear scaling factor for the built-in type
        OSP_INTENSITY_QUANTITY_UNKNOWN=5,
    ).items():
        setattr(lib, name, value)
    
    lib.ospInit.argtypes = [
        auto.ctypes.POINTER(auto.ctypes.c_int),
        auto.ctypes.POINTER(auto.ctypes.c_char_p),
    ]
    lib.ospInit.restype = lib.OSPError
    
    lib.ospCommit.argtypes = [lib.OSPObject]
    lib.ospCommit.restype = None
    
    lib.ospRetain.argtypes = [lib.OSPObject]
    lib.ospRetain.restype = None
    
    lib.ospRelease.argtypes = [lib.OSPObject]
    lib.ospRelease.restype = None
    
    lib.ospSetParam.argtypes = [lib.OSPObject, auto.ctypes.c_char_p, lib.OSPDataType, auto.ctypes.c_void_p]
    lib.ospSetParam.restype = None
    
    
    #--- Data
    
    lib.ospNewSharedData.argtypes = [
        auto.ctypes.c_void_p,
        lib.OSPDataType,
        auto.ctypes.c_uint64, auto.ctypes.c_int64,
        auto.ctypes.c_uint64, auto.ctypes.c_int64,
        auto.ctypes.c_uint64, auto.ctypes.c_int64,
    ]
    lib.ospNewSharedData.restype = lib.OSPData
    
    lib.ospNewData.argtypes = [
        lib.OSPDataType,
        auto.ctypes.c_uint64,
        auto.ctypes.c_uint64,
        auto.ctypes.c_uint64,
    ]
    lib.ospNewData.restype = lib.OSPData
    
    lib.ospCopyData.argtypes = [
        lib.OSPData,
        lib.OSPData,
        auto.ctypes.c_uint64,
        auto.ctypes.c_uint64,
        auto.ctypes.c_uint64,
    ]
    lib.ospCopyData.restype = None
    
    
    #--- Constructors
    
    lib.ospNewWorld.argtypes = []
    lib.ospNewWorld.restype = lib.OSPWorld
    
    lib.ospNewInstance.argtypes = [lib.OSPGroup]
    lib.ospNewInstance.restype = lib.OSPInstance
    
    lib.ospNewGroup.argtypes = []
    lib.ospNewGroup.restype = lib.OSPGroup
    
    lib.ospNewGeometricModel.argtypes = [lib.OSPGeometry]
    lib.ospNewGeometricModel.restype = lib.OSPGeometricModel
    
    lib.ospNewGeometry.argtypes = [auto.ctypes.c_char_p]
    lib.ospNewGeometry.restype = lib.OSPGeometry
    
    lib.ospNewMaterial.argtypes = [auto.ctypes.c_void_p, auto.ctypes.c_char_p]
    lib.ospNewMaterial.restype = lib.OSPMaterial
    
    lib.ospNewRenderer.argtypes = [auto.ctypes.c_char_p]
    lib.ospNewRenderer.restype = lib.OSPRenderer
    
    lib.ospNewCamera.argtypes = [auto.ctypes.c_char_p]
    lib.ospNewCamera.restype = lib.OSPCamera
    
    lib.ospNewTexture.argtypes = [auto.ctypes.c_char_p]
    lib.ospNewTexture.restype = lib.OSPTexture
    
    lib.ospNewLight.argtypes = [auto.ctypes.c_char_p]
    lib.ospNewLight.restype = lib.OSPLight
    
    lib.ospNewFrameBuffer.argtypes = [
        auto.ctypes.c_int, auto.ctypes.c_int,
        lib.OSPFrameBufferFormat,
        lib.OSPFrameBufferChannel,
    ]
    lib.ospNewFrameBuffer.restype = lib.OSPFrameBuffer
    
    lib.ospMapFrameBuffer.argtypes = [lib.OSPFrameBuffer, lib.OSPFrameBufferChannel]
    lib.ospMapFrameBuffer.restype = auto.ctypes.c_void_p
    
    lib.ospUnmapFrameBuffer.argtypes = [auto.ctypes.c_void_p, lib.OSPFrameBuffer]
    lib.ospUnmapFrameBuffer.restype = None
    
    lib.OSPBounds = type('OSPBounds', (auto.ctypes.Structure,), {
        '_fields_': [
            ('xlo', auto.ctypes.c_float),
            ('ylo', auto.ctypes.c_float),
            ('zlo', auto.ctypes.c_float),
            ('xhi', auto.ctypes.c_float),
            ('yhi', auto.ctypes.c_float),
            ('zhi', auto.ctypes.c_float),
        ],
    })
        
    lib.ospGetBounds.argtypes = [lib.OSPObject]
    lib.ospGetBounds.restype = lib.OSPBounds
    
    
    #--- Utilities

    lib.ospNewSharedData1D.argtypes = [
        auto.ctypes.c_void_p, lib.OSPDataType,
        auto.ctypes.c_uint64,
    ]
    lib.ospNewSharedData1D.restype = lib.OSPData
    
    lib.ospNewSharedData2D.argtypes = [
        auto.ctypes.c_void_p, lib.OSPDataType,
        auto.ctypes.c_uint64, auto.ctypes.c_uint64,
    ]
    lib.ospNewSharedData2D.restype = lib.OSPData
    
    lib.ospNewSharedData3D.argtypes = [
        auto.ctypes.c_void_p, lib.OSPDataType,
        auto.ctypes.c_uint64, auto.ctypes.c_uint64, auto.ctypes.c_uint64,
    ]
    lib.ospNewSharedData3D.restype = lib.OSPData
    
    
    lib.ospNewData1D.argtypes = [
        lib.OSPDataType,
        auto.ctypes.c_uint64,
    ]
    lib.ospNewData1D.restype = lib.OSPData
    
    lib.ospNewData2D.argtypes = [
        lib.OSPDataType,
        auto.ctypes.c_uint64, auto.ctypes.c_uint64,
    ]
    lib.ospNewData2D.restype = lib.OSPData
    
    
    lib.ospCopyData1D.argtypes = [
        lib.OSPData, lib.OSPData,
        auto.ctypes.c_uint64,
    ]
    lib.ospCopyData1D.restype = None
    
    lib.ospCopyData2D.argtypes = [
        lib.OSPData, lib.OSPData,
        auto.ctypes.c_uint64, auto.ctypes.c_uint64,
    ]
    lib.ospCopyData2D.restype = None
    
    
    def __define_setter(suffix: str, /, *argtypes: list, n=1):
        assert len(argtypes) > 0
        getattr(lib, f'ospSet{suffix}').argtypes = [
            lib.OSPObject, auto.ctypes.c_char_p,
            *(argtypes * n),
        ]
        getattr(lib, f'ospSet{suffix}').restype = None
        
    __define_setter('String', auto.ctypes.c_char_p)
    __define_setter('Object', lib.OSPObject)
    
    __define_setter('Bool', auto.ctypes.c_int)
    __define_setter('Float', auto.ctypes.c_float)
    __define_setter('Int', auto.ctypes.c_int)
    
    __define_setter('Vec2f', auto.ctypes.c_float, n=2)
    __define_setter('Vec3f', auto.ctypes.c_float, n=3)
    __define_setter('Vec4f', auto.ctypes.c_float, n=4)
    
    __define_setter('Vec2i', auto.ctypes.c_int, n=2)
    __define_setter('Vec3i', auto.ctypes.c_int, n=3)
    __define_setter('Vec4i', auto.ctypes.c_int, n=4)
    
    lib.ospSetObjectAsData.argtypes = [
        lib.OSPObject, auto.ctypes.c_char_p,
        lib.OSPDataType, lib.OSPObject,
    ]
    
    
    lib.ospRenderFrameBlocking.argtypes = [lib.OSPFrameBuffer, lib.OSPRenderer, lib.OSPCamera, lib.OSPWorld]
    lib.ospRenderFrameBlocking.restype = auto.ctypes.c_float

# %% [markdown]
# # Render

# %%
@run(scope='render', after=print)
def lib(ospray__lib, /):
    return ospray__lib
# Out:
# <CDLL '/home/raustin9/src/Sunrise-Demo/tmp/ospray-2.12.0/lib/libospray.so', handle 5613ac260fd0 at 0x7f9174f63070>

# %% [markdown]
# ## Terrain (OSPGeometry)

# %%
@run(scope='render', after=print)
def terrain(lib, interpolate, /):
    """mesh/OSPGeometry:mesh:position/vertex.position:vec3f[]+index/index:vec4ui[]"""
    rlo, rhi = 3299840, 3310591
    clo, chi = 2236928, 2259455
    rs = auto.numpy.arange(rlo, rhi)
    cs = auto.numpy.arange(clo, chi)

    def decimate(
        rs: auto.np.ndarray,
        cs: auto.np.ndarray,
        /,
        *,
        duration: 'seconds',
        rate: 'item/s',
    ) -> tuple[auto.np.ndarray, auto.np.ndarray]:
        total_items = len(rs) * len(cs)

        actual_items = duration * rate
    #             print(f'{items = } = {duration} * {rate}')

        factor_items = total_items / actual_items

        stride = int(auto.math.ceil(auto.math.sqrt( factor_items )))

    #             stride = int(auto.math.ceil())
    #             print(f'{stride = } = int(auto.math.ceil( {len(rs)} / {items} == {len(rs)/items} ))')

        rs = rs[::stride]
        cs = cs[::stride]

        print(f'Decimate by factor of {stride}**2={stride**2 :,d} from {total_items :,d} to {len(rs)*len(cs) :,d} vertices')
        return rs, cs

    rs, cs = decimate(
        rs, cs,
        duration=[
            1,  # lo resolution
            10,  # medium resolution
            1000,  # high resolution
        ][TERRAIN_QUALITY],
        rate=6260094,
    )

    position: 'OSPGeometry:mesh:vertex.position:vec3f[]' = auto.numpy.zeros(
        shape=(len(rs), len(cs)),
        dtype=[
            ('x', 'f4'),
            ('y', 'f4'),
            ('z', 'f4'),
        ],
    )
    
    texcoord: 'OSPGeometry:mesh:vertex.texcoord:vec2f[]' = auto.numpy.zeros(
        shape=(len(rs), len(cs)),
        dtype=[
            ('u', 'f4'),
            ('v', 'f4'),
        ],
    )
        
    normal: 'OSPGeometry:mesh:vertex.normal:vec3f[]' = auto.numpy.zeros(
        shape=(len(rs), len(cs)),
        dtype=[ ('x', 'f4'), ('y', 'f4'), ('z', 'f4') ],
    )
    
    @auto.mediocreatbest.immediate
    def __vert():
        with auto.tqdm.notebook.tqdm(total=position.size, unit='vert') as tqdm:
            for ri, r in enumerate(rs):
                lat, lngs = convert_tile_coordinates_to_latlng(
                    z=Tixel.z,
                    y=r,
                    x=cs,
                    math=auto.numpy,
                )

                if ri == 0:
                    print(lat, lngs[0])
                elif ri == len(rs) - 1:
                    print(lat, lngs[-1])
                
                # r: float
                # cs: list[float]
                
                # rs: list[float]
                
                # grid: list[tuple[float, float]]

                grid = auto.numpy.hstack(tuple(
                    v.reshape((-1, 1))
                    for v in auto.numpy.meshgrid(
                        [r],
                        cs,
                        indexing='ij',
                    )
                ))
                assert grid.shape == (len(cs), 2), \
                    f"""Wrong shape: {grid.shape=!r}"""

                alts = interpolate.elevation(
                    grid,
                    method='linear',
                )
                assert alts.shape == (len(cs),), \
                    f"""Wrong shape: {alts.shape=!r}"""

                Zmin = 0; Zmax = 1
                # Zmin = 0.2527998
                # Zmax = 2.02335

                # xs = auto.numpy.linspace(0.0, 1.0, num=len(cs))
                # ys = auto.numpy.array([ri / len(rs)] * len(cs))
                xs = cs / (2 ** Tixel.z)
                xs = 1 - xs  # flip x
                # print(f'{cs[0]=!r} {Tixel.z=!r} {(Tixel.z**2)=!r}')
                assert auto.np.all(0.0 <= xs)
                assert auto.np.all(xs <= 1.0)
                ys = auto.numpy.array([r / (2 ** Tixel.z)] * len(cs))
                ys = 1 - ys  # flip y
                # print(f'{ri=}, {len(rs)=}, {Tixel.z=!r} {(Tixel.z**2)=!r}')
                assert auto.np.all(0.0 <= ys)
                assert auto.np.all(ys <= 1.0)
                zs = alts / 1000.0
                zs = (zs - Zmin) / (Zmax - Zmin)
                zs = -zs  # flip z
                assert xs.shape == (len(cs),), \
                    f"""Wrong shape: {xs.shape=!r} {len(cs)=!r}"""
                assert ys.shape == (len(cs),), \
                    f"""Wrong shape: {ys.shape=!r} {len(cs)=!r}"""
                assert zs.shape == (len(cs),), \
                    f"""Wrong shape: {zs.shape=!r} {len(cs)=!r}"""

                # xs, ys, zs = convert_location_to_spatial(
                #     lat=lats,
                #     lng=lngsu
                #     alt=alts,
                #     math=auto.numpy,
                # )
                # xs, ys, zs = (v/1000.0 for v in [xs, ys, zs])
                # assert xs.shape == (len(cs),), \
                #     f"""Wrong shape: {xs.shape=!r}"""

                position[ri, :]['x'] = xs
                position[ri, :]['y'] = ys
                position[ri, :]['z'] = zs
                
                normal[ri, :]['x'] = xs
                normal[ri, :]['y'] = ys
                normal[ri, :]['z'] = zs
                
                us = auto.numpy.linspace(0.0, 1.0, num=len(cs))
                vs = ri / len(rs)
                
                texcoord[ri, :]['u'] = us
                texcoord[ri, :]['v'] = vs

                tqdm.update(len(cs))

    print(f'Xmin={position["x"][0,0]}, Xmax={position["x"][-1,-1]}')
    print(f'Ymin={position["y"][0,0]}, Ymax={position["y"][-1,-1]}')
    print(f'Zmin={position["z"][0,0]}, Zmax={position["z"][-1,-1]}')

    print(f'{position["x"].min()=!r} ;; {position["x"].max()=!r}')
    print(f'{position["y"].min()=!r} ;; {position["y"].max()=!r}')
    print(f'{position["z"].min()=!r} ;; {position["z"].max()=!r}')

    print(f'{texcoord["u"].min()=!r} ;; {texcoord["u"].max()=!r}')
    print(f'{texcoord["v"].min()=!r} ;; {texcoord["v"].max()=!r}')

    # index = OSPGeometry:mesh:index:vec4ui[]
    index = auto.numpy.zeros(
        shape=(len(rs)-1, len(cs)-1),
        dtype=[
            ('a', 'u4'),
            ('b', 'u4'),
            ('c', 'u4'),
            ('d', 'u4'),
        ],
    )

    @auto.mediocreatbest.immediate
    def __face():
        def indexof(ri: int, ci: int, /) -> int:
            return ri * len(cs) + ci

        with auto.tqdm.auto.tqdm(total=index.size, unit='face') as tqdm:
            # a -1- b
            # |     |
            # 4     2
            # |     |
            # d -3- c

            for ri in range(0, len(rs)-1):
                cis = auto.numpy.arange(len(cs)-1, dtype='u4')

                a = indexof(ri+0, cis+0)
                b = indexof(ri+0, cis+1)
                c = indexof(ri+1, cis+1)
                d = indexof(ri+1, cis+0)

                index[ri, :]['a'] = a
                index[ri, :]['b'] = b
                index[ri, :]['c'] = c
                index[ri, :]['d'] = d
                tqdm.update(len(cis))

        return index

    print(f'{index["a"].min()=!r} ;; {index["a"].max()=!r}')
    print(f'{index["b"].min()=!r} ;; {index["b"].max()=!r}')
    print(f'{index["c"].min()=!r} ;; {index["c"].max()=!r}')
    print(f'{index["d"].min()=!r} ;; {index["d"].max()=!r}')
    
    
    def Flatten(data: auto.numpy.NDArray, /) -> auto.numpy.NDArray:
        return data.reshape((-1,))
    
    position = Flatten(position)
    normal = Flatten(normal)
    texcoord = Flatten(texcoord)
    index = Flatten(index)
    
    
    #--- Save to Disk
    
    def Save(data: auto.numpy.NDArray, /, *, path: auto.pathlib.Path):
        if not DO_SAVE:
            return
        
        path.parent.mkdir(parents=True, exist_ok=True)
        with open(path, 'wb') as f:
            print(f'Writing {len(data.shape)}I = {data.shape=!r} to {path=!r}')
            f.write(auto.struct.pack('I', len(data.shape)))
            f.write(auto.struct.pack(f'{len(data.shape)}I', *data.shape))
            data.tofile(f)
        print(f"Wrote {path.stat().st_size :,d} bytes to {path}")
    
    Save(
        position,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"park",
            f"OSPGeometry.mesh.vertex.position.vec3f.bin",
        ),
    )
    
    Save(
        normal,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"park",
            f"OSPGeometry.mesh.vertex.normal.vec3f.bin",
        ),
    )
    
    Save(
        texcoord,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"park",
            f"OSPGeometry.mesh.vertex.texcoord.vec2f.bin",
        ),
    )
    
    Save(
        index,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"park",
            f"OSPGeometry.mesh.index.vec4ui.bin",
        ),
    )
    
    
    #--- OSPRay

    terrain = lib.ospNewGeometry(b'mesh')
    
    @auto.mediocreatbest.immediate
    def position():
        dst = lib.ospNewData1D(lib.OSP_VEC3F, position.size)
        src = lib.ospNewSharedData1D(position.ctypes.data, lib.OSP_VEC3F, position.size)
        lib.ospCommit(src)
        lib.ospCopyData1D(src, dst, 0)
        lib.ospCommit(dst)
        lib.ospRelease(src)
        return dst
    lib.ospSetObject(terrain, b'vertex.position', position)
    
    @auto.mediocreatbest.immediate
    def normal():
        dst = lib.ospNewData1D(lib.OSP_VEC3F, normal.size)
        src = lib.ospNewSharedData1D(normal.ctypes.data, lib.OSP_VEC3F, normal.size)
        lib.ospCommit(src)
        lib.ospCopyData1D(src, dst, 0)
        lib.ospCommit(dst)
        lib.ospRelease(src)
        return dst
    lib.ospSetObject(terrain, b'vertex.normal', normal)
    
    @auto.mediocreatbest.immediate
    def texcoord():
        dst = lib.ospNewData1D(lib.OSP_VEC2F, texcoord.size)
        src = lib.ospNewSharedData1D(texcoord.ctypes.data, lib.OSP_VEC2F, texcoord.size)
        lib.ospCommit(src)
        lib.ospCopyData1D(src, dst, 0)
        lib.ospCommit(dst)
        lib.ospRelease(src)
        return dst
    lib.ospSetObject(terrain, b'vertex.texcoord', texcoord)
    
    @auto.mediocreatbest.immediate
    def index():
        dst = lib.ospNewData1D(lib.OSP_VEC4UI, index.size)
        src = lib.ospNewSharedData1D(index.ctypes.data, lib.OSP_VEC4UI, index.size)
        lib.ospCommit(src)
        lib.ospCopyData1D(src, dst, 0)
        lib.ospCommit(dst)
        lib.ospRelease(src)
        return dst
    lib.ospSetObject(terrain, b'index', index)
    
    lib.ospCommit(terrain)
    return terrain
# Out:
# Decimate by factor of 7**2=49 from 242,187,777 to 4,944,384 vertices
#   0%|          | 0/4944384 [00:00<?, ?vert/s]
# 35.79999392988526 -84.00146484375
# 35.425112713810655 -83.03475379943848
# Xmin=0.73333740234375, Xmax=0.7306520938873291
# Ymin=0.60662841796875, Ymax=0.6053475141525269
# Zmin=-0.2767001986503601, Zmax=-1.3886817693710327
# position["x"].min()=0.7306521 ;; position["x"].max()=0.7333374
# position["y"].min()=0.6053475 ;; position["y"].max()=0.6066284
# position["z"].min()=-2.02335 ;; position["z"].max()=-0.2527998
# texcoord["u"].min()=0.0 ;; texcoord["u"].max()=1.0
# texcoord["v"].min()=0.0 ;; texcoord["v"].max()=0.99934894
#   0%|          | 0/4939630 [00:00<?, ?face/s]
# index["a"].min()=0 ;; index["a"].max()=4941163
# index["b"].min()=1 ;; index["b"].max()=4941164
# index["c"].min()=3220 ;; index["c"].max()=4944383
# index["d"].min()=3219 ;; index["d"].max()=4944382
# ...

# %% [markdown]
# ## Colormap (OSPMaterial[])

# %%
@run(scope='render', after=print)
def colormap(lib, interpolate, /):
    def Data(array: auto.numpy.ndarray, /, *, type: lib.OSPDataType) -> lib.OSPData:
        if len(array.shape) == 0:
            array = array[None, None, None]

        elif len(array.shape) == 1:
            array = array[:, None, None]

        elif len(array.shape) == 2:
            array = array[:, :, None]
            
        elif len(array.shape) == 3:
            array = array[:, :, :]

        else:
            raise NotImplementedError()

        src = lib.ospNewSharedData(
            array.ctypes.data, type,
            array.shape[0], array.strides[0],
            array.shape[1], array.strides[1],
            array.shape[2], array.strides[2],
        )
        lib.ospCommit(src)

        dst = lib.ospNewData(type, *array.shape)
        lib.ospCopyData(src, dst, 0, 0, 0)
        lib.ospCommit(dst)

        lib.ospRelease(src)
        return dst

    # Thanks https://species.atlasofthesmokies.org/style.css
    pinks = auto.numpy.array([
        # Black, obviously.
        # Represents 0-25%
        [0, 0, 0],

        #> #legend-pink-50 { background-color: #f069a3; }
        # Represents 25-50%
        [247, 105, 164],

        #> #legend-pink-75 { background-color: #c31d8e; }
        # Represents 50-75%
        [196, 28, 142],

        #> #legend-pink-100 { background-color: #752879; }
        # Represents 75-100%
        [121, 0, 124],
    ], dtype=auto.numpy.uint8)

    rlo, rhi = 3297280, 3313656
    clo, chi = 2236928, 2259455
    rs = auto.numpy.linspace(rlo, rhi, num=1024 * 4)
    rs = rs[::-1]  # Flip Y
    cs = auto.numpy.linspace(clo, chi, num=2048 * 4)
    
    @auto.mediocreatbest.immediate
    @auto.mediocreatbest.coroutine
    def display():
        handle = auto.IPython.display.display(None, display_id=True)
        
        while True:
            obj = yield
            handle.update(obj)
    
    def Colormap(pi: int, /) -> lib.OSPTexture:
        rgb = auto.numpy.zeros(
            shape=(len(rs), len(cs)),
            dtype=[
                ('r', 'f4'),
                ('g', 'f4'),
                ('b', 'f4'),
            ],
        )
        
        for ri, r in enumerate(rs):
            grid = auto.numpy.hstack(tuple(
                v.reshape((-1, 1))
                for v in auto.numpy.meshgrid(
                    [r],
                    cs,
                    indexing='ij',
                )
            ))
            assert grid.shape == (len(cs), 2), \
                f"""Wrong shape: {grid.shape=!r}"""
#             print(f"""{grid[:, 0].min()=!r} ;; {grid[:, 0].max()=!r}
# {grid[:, 1].min()=!r} ;; {grid[:, 1].max()=!r}""")
            
            rgbs = interpolate.background(
                grid,
                method='linear',
            )
            assert rgbs.shape == (len(cs), 3), \
                f"""Wrong shape: {rgbs.shape=!r}"""
            
            def composite(background: 'RGB', foreground: 'RGB', *, alpha: float):
                return background * (1.0 - alpha) + foreground * alpha
            
            pink = pinks[None, pi, :]
            pink = pink.astype(auto.numpy.float32)
            pink /= 255.0
            
            if pi == 0:
                alpha = 0.0
            else:
                alpha = 0.5
            
            rgbs = composite(rgbs, pink, alpha=alpha)
            assert rgbs.shape == (len(cs), 3), \
                f"""Wrong shape: {rgbs.shape=!r}"""
            
            rgb['r'][ri, :] = rgbs[:, 0]
            rgb['g'][ri, :] = rgbs[:, 1]
            rgb['b'][ri, :] = rgbs[:, 2]

#         import numpy.lib.recfunctions
#         display.send(auto.PIL.Image.fromarray(
#             (255.0 * auto.numpy.lib.recfunctions.structured_to_unstructured(rgb)).astype(auto.numpy.uint8),
#             mode='RGB',
#         ))


        #--- Save to Disk

        def Save(data: auto.numpy.NDArray, /, *, path: auto.pathlib.Path):
            if not DO_SAVE:
                return
            
            path.parent.mkdir(parents=True, exist_ok=True)
            with open(path, 'wb') as f:
                f.write(auto.struct.pack('I', len(data.shape)))
                f.write(auto.struct.pack(f'{len(data.shape)}I', *data.shape))
                data.tofile(f)
            print(f"Wrote {path.stat().st_size :,d} bytes to {path}")

        Save(
            rgb,
            path=auto.pathlib.Path.cwd().joinpath(
                f"data",
                f"pink{pi}",
                f"OSPTexture.texture2d.data.vec3f.bin",
            ),
        )
        
        
        #--- OSPRay
        
        data = Data(rgb, type=lib.OSP_VEC3F)
        
        texture = lib.ospNewTexture(b'texture2d')
        lib.ospSetInt(texture, b'format', lib.OSP_TEXTURE_RGB32F)
        lib.ospSetObject(texture, b'data', data)
        lib.ospCommit(texture)
        
        return texture

    materials: 'OSPMaterial[]' = auto.numpy.zeros(
        shape=(len(pinks),),
        dtype=auto.numpy.uintp,
    )
    
    for pi in range(len(pinks)):
        map_kd: lib.OSPTexture = Colormap(pi)
        
        material = lib.ospNewMaterial(None, b'obj')
        lib.ospSetObject(material, b'map_kd', map_kd)
        lib.ospSetVec3f(material, b'ks', 1.0, 1.0, 1.0)
        lib.ospSetFloat(material, b'ns', 2.0)
        lib.ospCommit(material)
    
        materials[pi] = auto.ctypes.cast(material, auto.ctypes.c_void_p).value
    
    materials = Data(materials, type=lib.OSP_MATERIAL)
    
    return materials
# Out:
# None
# Wrote 402,653,196 bytes to /home/raustin9/src/Sunrise-Demo/data/pink0/OSPTexture.texture2d.data.vec3f.bin
# Wrote 402,653,196 bytes to /home/raustin9/src/Sunrise-Demo/data/pink1/OSPTexture.texture2d.data.vec3f.bin
# Wrote 402,653,196 bytes to /home/raustin9/src/Sunrise-Demo/data/pink2/OSPTexture.texture2d.data.vec3f.bin
# Wrote 402,653,196 bytes to /home/raustin9/src/Sunrise-Demo/data/pink3/OSPTexture.texture2d.data.vec3f.bin
# ...

# %% [markdown]
# ## Observation (uint[8])

# %%
@run(scope='render', after=print)
def observation(lib, interpolate, /) -> 'uint8[]':
    """OSPGeometricModel::index:uint8[]"""
    
    def Data(array: auto.numpy.ndarray, /, *, type: lib.OSPDataType) -> lib.OSPData:
        if len(array.shape) == 0:
            array = array[None, None, None]

        elif len(array.shape) == 1:
            array = array[:, None, None]

        elif len(array.shape) == 2:
            array = array[:, :, None]
            
        elif len(array.shape) == 3:
            array = array[:, :, :]

        else:
            raise NotImplementedError()

        src = lib.ospNewSharedData(
            array.ctypes.data, type,
            array.shape[0], array.strides[0],
            array.shape[1], array.strides[1],
            array.shape[2], array.strides[2],
        )
        lib.ospCommit(src)

        dst = lib.ospNewData(type, *array.shape)
        lib.ospCopyData(src, dst, 0, 0, 0)
        lib.ospCommit(dst)

        lib.ospRelease(src)
        return dst
    
    rlo, rhi = 3300096, 3310591
    clo, chi = 2236928, 2259455

    real_rlo = interpolate.observation.grid[0].min()
    real_rhi = interpolate.observation.grid[0].max()
    real_clo = interpolate.observation.grid[1].min()
    real_chi = interpolate.observation.grid[1].max()
    assert rlo >= real_rlo, \
        f'{rlo=!r} < {real_rlo=!r}'
    assert rhi <= real_rhi, \
        f'{rhi=!r} > {real_rhi=!r}'
    assert clo >= real_clo, \
        f'{clo=!r} < {real_clo=!r}'
    assert chi <= real_chi, \
        f'{chi=!r} > {real_chi=!r}'

    rs = auto.numpy.arange(rlo, rhi)
    cs = auto.numpy.arange(clo, chi)

    def decimate(
        rs: auto.np.ndarray,
        cs: auto.np.ndarray,
        /,
        *,
        duration: 'seconds',
        rate: 'item/s',
    ) -> tuple[auto.np.ndarray, auto.np.ndarray]:
        total_items = len(rs) * len(cs)

        actual_items = duration * rate
    #             print(f'{items = } = {duration} * {rate}')

        factor_items = total_items / actual_items

        stride = int(auto.math.ceil(auto.math.sqrt( factor_items )))

    #             stride = int(auto.math.ceil())
    #             print(f'{stride = } = int(auto.math.ceil( {len(rs)} / {items} == {len(rs)/items} ))')

        rs = rs[::stride]
        cs = cs[::stride]

        print(f'Decimate by factor of {stride}**2={stride**2 :,d} from {total_items :,d} to {len(rs)*len(cs) :,d} vertices')
        return rs, cs

    rs, cs = decimate(
        rs, cs,
        duration=[
            1,  # lo resolution
            10,  # medium resolution
            1000,  # high resolution
        ][TERRAIN_QUALITY],
        rate=6260094,
    )
    
    index = auto.numpy.zeros(
        shape=(len(rs), len(cs)),
        dtype='u1',
    )
    
    for (ri, r) in enumerate(auto.tqdm.autonotebook.tqdm(rs, unit='row')):
        grid = auto.numpy.hstack(tuple(
            v.reshape((-1, 1))
            for v in auto.numpy.meshgrid(
                [r],
                cs,
                indexing='ij',
            )
        ))
        assert grid.shape == (len(cs), 2), \
            f"""Wrong shape: {grid.shape=!r}"""
#             print(f"""{grid[:, 0].min()=!r} ;; {grid[:, 0].max()=!r}
# {grid[:, 1].min()=!r} ;; {grid[:, 1].max()=!r}""")
        
        category = interpolate.observation(
            grid,
            method='nearest',
        )
        assert category.shape == (len(cs),), \
            f"""Wrong shape: {category.shape=!r}"""
        assert auto.numpy.all((0 <= category) & (category < 4))
        
        index[ri, :] = category
    
    index = index.reshape((-1,))
    print(auto.collections.Counter(index.flat))
    
    
    #--- Save to Disk

    def Save(data: auto.numpy.NDArray, /, *, path: auto.pathlib.Path):
        if not DO_SAVE:
            return
        
        path.parent.mkdir(parents=True, exist_ok=True)
        with open(path, 'wb') as f:
            f.write(auto.struct.pack('I', len(data.shape)))
            f.write(auto.struct.pack(f'{len(data.shape)}I', *data.shape))
            data.tofile(f)
        print(f"Wrote {path.stat().st_size :,d} bytes to {path}")

    Save(
        index,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"observation",
            f"OSPGeometricModel.index.vec1uc.bin",
        ),
    )
    
    
    #--- OSPRay
    
    index = Data(index, type=lib.OSP_UCHAR)
    return index
# Out:
# Decimate by factor of 7**2=49 from 242,187,777 to 4,944,384 vertices
#   0%|          | 0/1536 [00:00<?, ?row/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 @run(scope='render', after=print)
# ----> 2 def observation(lib, interpolate, /) -> 'uint8[]':
#       3     """OSPGeometricModel::index:uint8[]"""
#       5     def Data(array: auto.numpy.ndarray, /, *, type: lib.OSPDataType) -> lib.OSPData:
#
# File ~/.local/lib/python3.10/site-packages/mediocreatbest.py:558, in run.<locals>.wrapper(func, name, cond)
#     555         if name in g:
#     556             return
# --> 558 ret = func(*args)
#     560 if callable(after):
#     561     after(ret)
#
# Cell In[17], line 96, in observation(lib, interpolate)
#      91         assert grid.shape == (len(cs), 2), \
#      92             f"""Wrong shape: {grid.shape=!r}"""
# ...

# %% [markdown]
# ## OSPWorld

# %%
@run(scope='render', after=print)
def world(lib, terrain, colormap, observation, /):
    with auto.contextlib.ExitStack() as stack:
        enter = stack.enter_context
        defer = stack.callback
        
        # model/OSPGeometricModel::geometry:OSPGeometry=terrain+material:OSPMaterial=material
        model = lib.ospNewGeometricModel(None)
        lib.ospSetObject(model, b'geometry', terrain)
        lib.ospSetObject(model, b'material', colormap)
        lib.ospSetObject(model, b'index', observation)
        lib.ospCommit(model)
#         defer(lib.ospRelease, model)
        
        # group/OSPGroup::geometry:OSPGeometricModel[]=model
        group = lib.ospNewGroup()
        lib.ospSetObjectAsData(group, b'geometry', lib.OSP_GEOMETRIC_MODEL, model)
        lib.ospCommit(group)
#         defer(lib.ospRelease, group)
        
        # instance/OSPInstance::group:OSPGroup=group
        instance = lib.ospNewInstance(None)
        lib.ospSetObject(instance, b'group', group)
        lib.ospCommit(instance)
#         defer(lib.ospRelease, instance)
        
        # world/OSPWorld::instance:OSPInstance[]=instance
        world = lib.ospNewWorld()
        lib.ospSetObjectAsData(world, b'instance', lib.OSP_INSTANCE, instance)
        lib.ospCommit(world)
        pass  # defer(lib.ospRelease, world)

    bounds = lib.ospGetBounds(world)
    print(f'{bounds = !r}')
    print(bounds.xlo, bounds.ylo, bounds.zlo)
    print(bounds.xhi, bounds.yhi, bounds.zhi)

    return world

# %% [markdown]
# ## OSPCamera

# %%
@run(scope='render', after=print)
def camera(lib, /):
    return lib.ospNewCamera(b'panoramic')

# %% [markdown]
# ## OSPRenderer

# %%
@run(scope='render', after=print)
def renderer(lib, /):
    renderer = lib.ospNewRenderer(b'pathtracer')
    lib.ospSetInt(renderer, b'pixelSamples', 32)
    lib.ospCommit(renderer)
    return renderer

# %% [markdown]
# ## Load Trail

# %%
@auto.dataclasses.dataclass(eq=True, frozen=True)
class View:
    position: tuple[float, float, float]
    up: tuple[float, float, float]
    direction: tuple[float, float, float]
        
    def __post_init__(self):
        def unit(v: auto.numpy.typing.ArrayLike):
            v = auto.numpy.asarray(v)
            v = v / auto.numpy.linalg.norm(v)
            return v
        
        unit_up = unit(self.up)
        unit_direction = unit(self.direction)
        assert (dot := auto.numpy.dot(unit_up, unit_direction) < 0.99), \
            f"""View up and direction are too similar: {dot=!r}"""
        
@run(scope='render')
def views() -> list[View]:
    with open(auto.pathlib.Path.cwd() / 'data' / 'Appalachian_Trail.json', 'r') as f:
        trail = auto.json.load(f)

#         trail = trail[::8]

    views = []
    for window in auto.more_itertools.sliding_window(trail, 3 * (k := 4)):
        srcs = window[:k]
        tgts = window[-k:]
        assert len(srcs) == k
        assert len(tgts) == k

        src_lat = auto.statistics.fmean(src["lat"] for src in srcs)
        src_lng = auto.statistics.fmean(src["lng"] for src in srcs)
        src_alt: Meter = 2_000 # * auto.random.uniform(0.9, 1.1)

        tgt_lat = auto.statistics.fmean(tgt["lat"] for tgt in tgts)
        tgt_lng = auto.statistics.fmean(tgt["lng"] for tgt in tgts)
        tgt_alt: Meter = 1_500 # * auto.random.uniform(0.9, 1.1)

        src_x, src_y, src_z = map(lambda x: x/1000, convert_location_to_spatial(
            lat=src_lat,
            lng=src_lng,
            alt=src_alt,
        ))

        tgt_x, tgt_y, tgt_z = map(lambda x: x/1000, convert_location_to_spatial(
            lat=tgt_lat,
            lng=tgt_lng,
            alt=tgt_alt,
        ))

        views.append(View(
            position=(
                src_x,
                src_y,
                src_z,
            ),
            up=(
                src_x,
                src_y,
                src_z,
            ),
            direction=(
                tgt_x - src_x,
                tgt_y - src_y,
                tgt_z - src_z,
            ),
        ))

    return views

# %%
@run(scope='render')
def __save_views(views, /):
    views = views[:-30]
    NV = len(views)
    
    position = auto.numpy.zeros(
        shape=(NV, 1),
        dtype=[ ('x', 'f4'), ('y', 'f4'), ('z', 'f4') ],
    )
    
    up = auto.numpy.zeros(
        shape=(NV, 1),
        dtype=[ ('x', 'f4'), ('y', 'f4'), ('z', 'f4') ],
    )
    
    direction = auto.numpy.zeros(
        shape=(NV, 1),
        dtype=[ ('x', 'f4'), ('y', 'f4'), ('z', 'f4') ],
    )
    
    for i, view in enumerate(views):
        position [i, :] = view.position
        up       [i, :] = view.up
        direction[i, :] = view.direction
    
    
    #--- Save to Disk

    def Save(data: auto.numpy.NDArray, /, *, path: auto.pathlib.Path):
        if not DO_SAVE:
            return
        
        path.parent.mkdir(parents=True, exist_ok=True)
        data.tofile(path)
        print(f"Wrote {path.stat().st_size :,d} bytes to {path}")

    Save(
        position,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"camera",
            f"OSPCamera.panoramic.position.vec3f.bin",
        ),
    )
    
    Save(
        up,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"camera",
            f"OSPCamera.panoramic.up.vec3f.bin",
        ),
    )
    
    Save(
        direction,
        path=auto.pathlib.Path.cwd().joinpath(
            f"data",
            f"camera",
            f"OSPCamera.panoramic.direction.vec3f.bin",
        ),
    )

# %% [markdown]
# ## Render Single

# %%
@run(scope='render', after=auto.IPython.display.display)
def __render(lib, renderer, camera, world, views, /):
    vi = 100
    view = views[vi]

    when = auto.datetime.datetime(year=2023, month=6, day=1, hour=12, tzinfo=auto.datetime.timezone(
        auto.datetime.timedelta(hours=-5),
        name='EST',
    ))
    
    lat, lng = convert_date_to_sun_location(when)
    lat, lng = 35.907393, -84.006166
    
    print(f'{lat=!r} {lng=!r}')
    x, y, z = convert_location_to_spatial(lat=lat, lng=lng, alt=10_000.0)
    print(f'{x=!r} {y=!r} {z=!r}')

    light = lib.ospNewLight(b'sunSky')
    lib.ospSetVec3f(light, b'color', 0.7, 0.7, 0.7)
    lib.ospSetFloat(light, b'intensity', 3.0)
    lib.ospSetVec3f(light, b'position', x, y, z)
#     lib.ospSetVec3f(light, b'direction', -x, -y, -z)
    lib.ospSetVec3f(light, b'up', x, y, z)
    lib.ospCommit(light)

    lib.ospSetObjectAsData(world, b'light', lib.OSP_LIGHT, light)
    lib.ospCommit(world)
    lib.ospRelease(light)
    
    lib.ospSetVec3f(camera, b'position', *view.position)
    lib.ospSetVec3f(camera, b'up', *view.up)
    lib.ospSetVec3f(camera, b'direction', *view.direction)
    lib.ospCommit(camera)
    
    lib.ospSetVec3f(renderer, b'backgroundColor', *(
#         0.7, 0.3, 0.7,
        0.0, 0.0, 0.0
    ))
    lib.ospCommit(renderer)
    
    w, h = 1024, 512

    framebuffer = lib.ospNewFrameBuffer(w, h, lib.OSP_FB_RGBA8, lib.OSP_FB_COLOR)
    _: float = lib.ospRenderFrameBlocking(
        framebuffer,
        renderer,
        camera,
        world,
    )

    rgba = lib.ospMapFrameBuffer(framebuffer, lib.OSP_FB_COLOR)
    image = auto.PIL.Image.frombytes(
        'RGB',
        (w, h),
        auto.ctypes.string_at(rgba, size=(w * h * 4)),
        'raw',
        'RGBX',
        0,
        -1,  # flip y
    )

    lib.ospUnmapFrameBuffer(rgba, framebuffer)

    return image

# %% [markdown]
# # Video

# %% [markdown]
# ## Animation Widget

# %%
@run(scope='render')
def animation():
    @auto.mediocreatbest.coroutine
    def animation(*, width: int, height: int) -> Generator[None, auto.PIL.Image.Image, None]:
        canvas = auto.ipycanvas.Canvas(width=width, height=height)
        auto.IPython.display.display(canvas)
        
        while True:
            image = yield
            image = auto.numpy.array(image)
            with auto.ipycanvas.hold_canvas():
                canvas.put_image_data(image)

    return animation

# %% [markdown]
# ## ffmpeg

# %%
@run(scope='render')
def ffmpeg():
    @auto.mediocreatbest.coroutine
    def ffmpeg(
        path: auto.pathlib.Path,
        /,
    ) -> Generator[None, auto.PIL.Image.Image, None]:
        process = None
        
        try:
            # Thanks https://stackoverflow.com/a/43871666
            process = auto.subprocess.Popen(
                args=[
                    'ffmpeg',
                    '-f', 'image2pipe',
                    '-vcodec', 'png',
                    '-r', '30',  # FPS
                    '-i', '-',
                    '-c:v', 'libx264',
                    '-crf', '23',
                    '-profile:v', 'baseline',
                    '-level', '3.0',
                    '-pix_fmt', 'yuv420p',
                    '-movflags', 'faststart',
                    '-y',  # overwrite
                    path,
                ],
                stdin=auto.subprocess.PIPE,
                stdout=auto.subprocess.DEVNULL,
                stderr=auto.subprocess.DEVNULL,
            )
            
            while True:
                image = yield
                
                image.save(process.stdin, format='PNG')
                process.stdin.flush()
        
        finally:
            if process is not None:
                try:
                    process.stdin.close()
                    process.wait(timeout=10)
                    
                except:
                    process.kill()
                    
    return ffmpeg

# %% [markdown]
# ## `render()`

# %%
@auto.dataclasses.dataclass(eq=True, frozen=True)
class Render:
    view: View
    when: auto.datetime.datetime

@run(scope='render')
def render(lib, renderer, camera, world, /):
    @auto.mediocreatbest.coroutine
    def render(
        *,
        width: int,
        height: int,
        format: auto.typing.Literal['RGB8', 'RGBA8']='RGB8',
    ) -> Generator[auto.PIL.Image.Image, View, None]:
        framebuffer = lib.ospNewFrameBuffer(width, height, lib.OSP_FB_RGBA8, lib.OSP_FB_COLOR)
        
        image = None
        while True:
            render = yield image
            
            lat, lng = convert_date_to_sun_location(render.when)
            x, y, z = convert_location_to_spatial(lat=lat, lng=lng, alt=10_000.0)
            
#             light = lib.ospNewLight(b'sunSky')
#             lib.ospSetVec3f(light, b'color', 0.7, 0.7, 0.7)
#             lib.ospSetFloat(light, b'intensity', 3.0)
#             lib.ospSetVec3f(light, b'position', x, y, z)
#             lib.ospSetVec3f(light, b'up', x, y, z)
#             lib.ospSetFloat(light, b'horizonExtension', 1.0)
#             lib.ospCommit(light)

#             light = lib.ospNewLight(b'sphere')
#             intensityQuantity = auto.ctypes.c_char(lib.OSP_INTENSITY_QUANTITY_INTENSITY)
#             lib.ospSetParam(light, b'intensityQuantity', lib.OSP_UCHAR, auto.ctypes.byref(intensityQuantity))
#             lib.ospSetFloat(light, b'intensity', 150000.0)
#             lib.ospSetVec3f(light, b'color', 0.7, 0.7, 0.7)
#             lib.ospSetVec3f(light, b'position', x, y, z)
#             lib.ospCommit(light)

            light = lib.ospNewLight(b'distant')
            lib.ospSetVec3f(light, b'position', x, y, z)
            lib.ospSetVec3f(light, b'direction', -x, -y, -z)
            lib.ospSetFloat(light, b'intensity', 1.8)
            lib.ospCommit(light)
            
            lib.ospSetObjectAsData(world, b'light', lib.OSP_LIGHT, light)
            lib.ospCommit(world)
            lib.ospRelease(light)
            
            lib.ospSetVec3f(camera, b'position', *render.view.position)
            lib.ospSetVec3f(camera, b'up', *render.view.up)
            lib.ospSetVec3f(camera, b'direction', *render.view.direction)
            lib.ospCommit(camera)

#             lib.ospSetInt(renderer, b'pixelSamples', view.pixelSamples)
            lib.ospSetVec4f(renderer, b'backgroundColor', *(
        #         0.7, 0.3, 0.7,
                0.0, 0.0, 0.0, 0.0,
            ))
            lib.ospSetInt(renderer, b'architectural', 1)
            lib.ospCommit(renderer)
            
            _: float = lib.ospRenderFrameBlocking(
                framebuffer,
                renderer,
                camera,
                world,
            )

            rgba = lib.ospMapFrameBuffer(framebuffer, lib.OSP_FB_COLOR)
            
            if format == 'RGB8':
                image = auto.PIL.Image.frombytes(
                    'RGB',
                    (width, height),
                    auto.ctypes.string_at(rgba, size=(width * height * 4)),
                    'raw',
                    'RGBX',
                    0,
                    -1,  # flip y
                )
            
            elif format == 'RGBA8':
                image = auto.PIL.Image.frombytes(
                    'RGBA',
                    (width, height),
                    auto.ctypes.string_at(rgba, size=(width * height * 4)),
                    'raw',
                    'RGBA',
                    0,
                    -1,  # flip y
                )

            lib.ospUnmapFrameBuffer(rgba, framebuffer)
    
    return render

# %% [markdown]
# ## Animate

# %%
@run(scope='render', after=auto.IPython.display.display)
def __animation(render, ffmpeg, animation, views, /):
    width, height = 1024, 512
    
    video = 'data/video.mp4'
    
    def Reduce(
        views: list[auto.typing.Annotated[auto.typing.Any, 'frame']],
        *lists: list[list[auto.typing.Annotated[auto.typing.Any, 'frame']]],
        rate: auto.typing.Annotated[float, 'frame/second'],
        duration: auto.typing.Annotated[float, 'second'],
    ):
        views = views[:-30]
        total_possible: auto.typing.Annotated[float, 'frame'] = duration / rate
        total_available: auto.typing.Annotated[int, 'frame'] = len(views)
        stride: auto.typing.Annotated[int, 'frame'] = int(auto.math.ceil( total_available / total_possible ))
        print(f"""Reduced from:
  {len(views)} frames for {len(views)/rate :.1f} seconds at {rate :.1f} frame/second""")
        views = views[::stride]
        lists = [ls[::stride] for ls in lists]
        print(f"""to:
  {len(views)} frames for {len(views)/rate :.1f} seconds at {rate :.1f} frame/second""")
        if lists:
            return [views, *lists]
        return views
    
    whens = []
    ref = auto.datetime.datetime(year=2023, month=6, day=1, hour=12, tzinfo=auto.datetime.timezone(
        auto.datetime.timedelta(hours=-5),
        name='EST',
    ))
    for i in range(len(views)):
        when = ref + auto.datetime.timedelta(minutes=i)
        whens.append(when)

    views, whens = Reduce(
        views,
        whens,
        rate=3.26,
        duration=[
            10,  # small
            30,  # medium
            1000,  # large
        ][VIDEO_QUALITY],
    )
    
    render = render(width=width, height=height)
    animation = animation(width=width, height=height)
    ffmpeg = ffmpeg(video)
    for view, when in auto.tqdm.auto.tqdm(
        zip(views, whens),
        total=len(views),
        unit='frame',
    ):
        image = render.send(Render(view=view, when=when))
        animation.send(image)
        ffmpeg.send(image)
    
    return auto.IPython.display.FileLink(video)

# %% [markdown]
# # Figure out OSPRay equirectangular coordinates

# %%
@run(scope='equi')
def lib(ospray__lib, /):
    return ospray__lib

# %%
class StupidTuple:
    def __init__(self, names=None):
        if names is None:
            names = []
            
        self.__names = names
        self.__class = None
        
    def __getattr__(self, name):
        attr = StupidTuple(self.__names + [name])
        setattr(self, name, attr)
        return attr
    
    def __call__(self, *args, **kwargs):
        if self.__class is None:
            typename = ''.join(name[0] for name in self.__names)
            fields = self.__names
            self.__class = auto.collections.namedtuple(typename, fields)
        
        return self.__class(*args, **kwargs)

stupidtuple = StupidTuple()

# %%
@run(scope='equi')
def defns():
    xpos = stupidtuple.x.y.z( 1.0,  0.0,  0.0)
    zpos = stupidtuple.x.y.z( 0.0,  0.0,  1.0)
    xneg = stupidtuple.x.y.z(-1.0,  0.0,  0.0)
    zneg = stupidtuple.x.y.z( 0.0,  0.0, -1.0)
    ypos = stupidtuple.x.y.z( 0.0,  1.0,  0.0)
    yneg = stupidtuple.x.y.z( 0.0, -1.0,  0.0)
    
    green   = stupidtuple.r.g.b(0.0, 1.0, 0.0)
    orange  = stupidtuple.r.g.b(1.0, 0.5, 0.5)
    magenta = stupidtuple.r.g.b(1.0, 0.0, 1.0)
    cyan    = stupidtuple.r.g.b(0.0, 1.0, 1.0)
    yellow  = stupidtuple.r.g.b(1.0, 1.0, 0.0)
    blue    = stupidtuple.r.g.b(0.0, 0.0, 1.0)
    
    return [
        stupidtuple.name.color.position('front',  green,   xpos),
        stupidtuple.name.color.position('right',  orange,  zpos),
        stupidtuple.name.color.position('back',   magenta, xneg),
        stupidtuple.name.color.position('left',   cyan,    zneg),
        stupidtuple.name.color.position('top',    yellow,  ypos),
        stupidtuple.name.color.position('bottom', blue,    yneg),
    ]

# %%
def affine3f(
    *,
    scale: float | tuple[float, float, float],
    translate: tuple[float, float, float],
) -> auto.numpy.ndarray[tuple[auto.typing.Literal[12]], auto.numpy.float32]:
    # In OSPRay, the affine3f type is implemented with a weird structure. This
    # structure corresponds with the C++ types:
    # 
    # class vec3f { float x, y, z; }
    # class linear3f { vec3f vx, vy, vz; }
    # class affine3f { linear3f l; vec3f p; }
    # 
    # If I am understanding correctly, we are meant to interpret the vx, vy, and vz
    # variables as vectors that get multiplied with the x, y, and z coordinates,
    # respectively.
    # 
    # There are two ways to view this structure then: 1) as a contiguous set of 12
    # floats, and 2) as an ordinary 4x4 projection matrix.
    # 
    # For (1), we can assign names to each variable, corresponding to this C++ code:
    # 
    # float a, b, c, d, e, f, g, h, i, j, k, l;
    # auto transform = affine3f{
    #     .l = {
    #         .vx = { .x = a, .y = b, .z = c },
    #         .vy = { .x = d, .y = e, .z = f },
    #         .vz = { .x = g, .y = h, .z = i },
    #     },
    #     .p = { .x = j, .y = k, .z = l },
    # };
    # 
    # Or, using an ordinary array of floats:
    # 
    # float transform[12] = {
    #     a, b, c,
    #     d, e, f,
    #     g, h, i,
    #     j, k, l,
    # };
    # 
    # For (2), we can rearrange the a, b, ..., l variables into an ordinary matrix:
    # 
    # [ a d g j ]   [ x ]   [ x' ]
    # [ b e h k ] x [ y ] = [ y' ]
    # [ c f i l ]   [ z ]   [ z' ]
    # [ 0 0 0 1 ]   [ 1 ]   [ 1  ]
    # 
    # It's important to note that data in a float array is stored transposed compared
    # to how it is used.
    # 
    # Regardless, for the simplest use case of a scale and then translate, we are only
    # interested in a few of the variables from the larger set of variables.
    # 
    # [ sx  0   0   tx ]
    # [ 0   sy  0   ty ]
    # [ 0   0   sz  tz ]
    # [ 0   0   0   1  ]
    # 
    # which corresponds to the floats:
    # 
    # float transform[12] = {
    #     sx, 0,  0,
    #     0,  sy, 0,
    #     0,  0,  sz,
    #     tx, ty, tz,
    # };
    
    match scale:
        case (sx, sy, sz):
            pass
        case float() as s:
            sx = sy = sz = s
        case _: raise NotImplementedError(f"""Unexpected scale: {scale=!r}""")
        
    tx, ty, tz = translate
    
    return auto.numpy.array([
        sx, 0,  0,
        0,  sy, 0,
        0,  0,  sz,
        tx, ty, tz,
    ], dtype=auto.numpy.float32)

# %%
@run(scope='equi', after=auto.IPython.display.display)
def image(lib, defns, /):
    def Data(array: auto.numpy.ndarray, /, *, type: lib.OSPDataType) -> lib.OSPData:
        if isinstance(array, list):
            for i, x in enumerate(array):
                if not isinstance(x, lib.OSPObject):
                    break
                
            else:
                print(f'Array of OSPObjects')
                array = (auto.ctypes.cast(x, auto.ctypes.c_void_p).value for x in array)
                array = auto.numpy.fromiter(array, dtype=auto.numpy.uintp)
                print(f'Now an array of: {array = !r}')
                return Data(array, type=type)
        
            print(f'Array of other things')
            array = auto.numpy.asarray(array)
            return Data(array, type=type)
        
        if len(array.shape) == 0:
            array = array[None, None, None]

        elif len(array.shape) == 1:
            array = array[:, None, None]

        elif len(array.shape) == 2:
            array = array[:, :, None]
            
        elif len(array.shape) == 3:
            array = array[:, :, :]

        else:
            raise NotImplementedError()

        src = lib.ospNewSharedData(
            array.ctypes.data, type,
            array.shape[0], array.strides[0],
            array.shape[1], array.strides[1],
            array.shape[2], array.strides[2],
        )
        lib.ospCommit(src)

        dst = lib.ospNewData(type, *array.shape)
        lib.ospCopyData(src, dst, 0, 0, 0)
        lib.ospCommit(dst)

        lib.ospRelease(src)
        return dst
        
    with auto.contextlib.ExitStack() as stack:
        defer = stack.callback
        
        position = auto.numpy.zeros(
            shape=(len(defns), 1),
            dtype=[ ('x', 'f4'), ('y', 'f4'), ('z', 'f4') ],
        )
        for i, defn in enumerate(defns):
            position['x'][i, 0] = defn.position.x
            position['y'][i, 0] = defn.position.y
            position['z'][i, 0] = defn.position.z

        position = Data(position, type=lib.OSP_VEC3F)
        defer(lib.ospRelease, position)

        geometry = lib.ospNewGeometry(b'sphere')
        lib.ospSetObject(geometry, b'sphere.position', position)
        lib.ospSetFloat(geometry, b'radius', 0.5)
        lib.ospCommit(geometry)
        defer(lib.ospRelease, geometry)
            
        color = auto.numpy.zeros(
            shape=(len(defns), 1),
            dtype=[ ('r', 'f4'), ('g', 'f4'), ('b', 'f4'), ('a', 'f4') ]
        )
        for i, defn in enumerate(defns):
            color['r'][i, 0] = defn.color.r
            color['g'][i, 0] = defn.color.g
            color['b'][i, 0] = defn.color.b
            color['a'][i, 0] = 1.0
        
        color = Data(color, type=lib.OSP_VEC4F)
        defer(lib.ospRelease, color)
        
        material = lib.ospNewMaterial(None, b'obj')
        lib.ospCommit(material)
        defer(lib.ospRelease, material)

        model = lib.ospNewGeometricModel(None)
        lib.ospSetObject(model, b'geometry', geometry)
        lib.ospSetObject(model, b'color', color)
        lib.ospSetObject(model, b'material', material)
        lib.ospCommit(model)
        defer(lib.ospRelease, model)

        group = lib.ospNewGroup()
        lib.ospSetObjectAsData(group, b'geometry', lib.OSP_GEOMETRIC_MODEL, model)
        lib.ospCommit(group)
        defer(lib.ospRelease, group)

        @list
        @auto.mediocreatbest.immediate
        def instance():
            for defn in [
                stupidtuple.position.scale(stupidtuple.x.y.z( 0.0, 0.0, 0.0 ), 1.0),
            ] + [
                stupidtuple.position.scale(defn.position, 0.4)
                for defn in defns
            ]:
                transform = affine3f(scale=defn.scale, translate=defn.position)
                
                instance = lib.ospNewInstance(None)
                lib.ospSetObject(instance, b'group', group)
                lib.ospSetParam(instance, b'transform', lib.OSP_AFFINE3F, transform.ctypes.data)
                lib.ospCommit(instance)
                defer(lib.ospRelease, instance)
                
                yield instance

        print(instance)

        instance = Data(instance, type=lib.OSP_INSTANCE)
        defer(lib.ospRelease, instance)

        world = lib.ospNewWorld()
        lib.ospSetObject(world, b'instance', instance)
        lib.ospCommit(world)
        defer(lib.ospRelease, world)

        camera = lib.ospNewCamera(b'panoramic')
        lib.ospSetVec3f(camera, b'position', 0.0, 0.0, 0.0)
        lib.ospSetVec3f(camera, b'direction', 1.0, 0.0, 0.0)
        lib.ospSetVec3f(camera, b'up', 0.0, 1.0, 0.0)
        lib.ospCommit(camera)
        defer(lib.ospRelease, camera)

        renderer = lib.ospNewRenderer(b'ao')
        lib.ospSetInt(renderer, b'pixelSamples', 32)
        lib.ospCommit(renderer)
        defer(lib.ospRelease, renderer)

        w, h = 1024, 512

        framebuffer = lib.ospNewFrameBuffer(w, h, lib.OSP_FB_RGBA8, lib.OSP_FB_COLOR)
        defer(lib.ospRelease, framebuffer)
        
        _: float = lib.ospRenderFrameBlocking(
            framebuffer,
            renderer,
            camera,
            world,
        )

        rgba = lib.ospMapFrameBuffer(framebuffer, lib.OSP_FB_COLOR)
        defer(lib.ospUnmapFrameBuffer, rgba, framebuffer)
        
        image = auto.PIL.Image.frombytes(
            'RGB',
            (w, h),
            auto.ctypes.string_at(rgba, size=(w * h * 4)),
            'raw',
            'RGBX',
            0,
            -1,  # flip y
        )

        return image

# %% [markdown]
# # Sunrise-as-a-Service

# %% [markdown]
# ## Inputs

# %%
@run(scope='service')
def render(render__render, /):
    return render__render

@run(scope='service')
def Animation(render__animation, /):
    return render__animation

# %% [markdown]
# ## `patchbay.pub`

# %%
@auto.dataclasses.dataclass(eq=True, frozen=True)
class Request:
    path: str
    query: dict[AnyStr, AnyStr]
    body: bytes | None

@auto.dataclasses.dataclass(eq=True, frozen=True)
class Response:
    status: int
    content_type: str
    data: AnyStr | dict[AnyStr, AnyStr]

@run(scope='service')
def server():
    patchbay = 'https://patchbay.pub'
    
    def server(*, primary: str, verbose=False):
        def http(*, method, url, data=None, headers=None) -> auto.requests.Response:
            if verbose:
                print(f'http(\n  {method=!r},\n  {url=!r},\n  {data=!r},\n  {headers=!r},\n)')

            return auto.requests.request(
                method=method,
                url=url,
                data=data,
                headers=headers,
            )
        
        secondary = auto.uuid.uuid4().hex

        print(f'Listening at {auto.urllib.parse.urljoin(patchbay, f"/req/{primary}/")}')
        while True:
            with http(
                method='POST',
                url=auto.urllib.parse.urljoin(patchbay, f'/res/{primary}?switch=true'),
                data=f'{secondary}',
            ) as r:
                r.raise_for_status()
                
                uri = r.headers['pb-uri']
                uri = auto.urllib.parse.urljoin(patchbay, uri)
                _scheme, _netloc, path, _params, query, _fragment = auto.urllib.parse.urlparse(uri)
                query = auto.urllib.parse.parse_qs(query)
                path = path.removeprefix(f'/req/{primary}')
                body = r.content
                request = Request(
                    path=path,
                    query=query,
                    body=body,
                )
                
            response = yield request
            if response is None:
                response = Response(
                    status=500,
                    content_type='text/plain',
                    data=b'500 Internal Server Error',
                )
            
            with http(
                method='POST',
                url=auto.urllib.parse.urljoin(patchbay, f'/{secondary}'),
                data=response.data,
                headers={
                    'Pb-Status': str(response.status),
                    'Pb-H-Content-Type': response.content_type,
                },
            ) as r:
                r.raise_for_status()

    return server

# %% [markdown]
# ## `index.html`

# %%
# %%verbatim -v __index_html
# <!DOCTYPE html>
# <meta charset="UTF-8">
# <title></title>
# <style>
# * {
#     margin: 0;
#     padding: 0;
#     box-sizing: border-box;
# }
# </style>
# <div id=app>
# </div>
# <script async src="https://unpkg.com/es-module-shims@1.6.3/dist/es-module-shims.js"></script>
# <script type="importmap">
# {
#     "imports": {
#         "three": "https://unpkg.com/three@${THREE_VERSION}/build/three.module.js",
#         "three/addons/": "https://unpkg.com/three@${THREE_VERSION}/examples/jsm/"
#     }
# }
# </script>
# <script src="https://unpkg.com/@babel/standalone@7.22.9/babel.min.js"></script>
# <script type="text/babel" data-plugins="syntax-do-expressions,proposal-do-expressions" data-type="module">
# import * as THREE from 'three';
# import { ARButton } from 'three/addons/webxr/ARButton.js';
# import { TrackballControls } from 'three/addons/controls/TrackballControls.js';
#
# const renderer = do {
#     const alpha = true;
#     const antialias = true;
#     new THREE.WebGLRenderer({ alpha, antialias });
# };
# renderer.setPixelRatio(window.devicePixelRatio);
# renderer.setSize(window.innerWidth, window.innerHeight);
# renderer.autoClear = false;
# renderer.xr.enabled = true;
# renderer.setAnimationLoop(render);
# document.body.appendChild(renderer.domElement);
#
# {
#     const button = ARButton.createButton(renderer);
#     document.body.appendChild(button);
# };
#
# const scene = do {
#     new THREE.Scene();
# };
# scene.background = new THREE.Color(0x505050);
#
# const camera = do {
#     const fov = 77;
#     const aspect = do {
#         const { x: width, y: height } = renderer.getSize(new THREE.Vector2());
#         width / height;
#     };
#     const near = 0.1;
#     const far = 100.0;
#     new THREE.PerspectiveCamera(fov, aspect, near, far);
# };
# camera.position.set(0.0, 0.0, 0.0);
# camera.up.set(0.0, 1.0, 0.0);
# camera.lookAt(1.0, 0.0, 0.0);
#
# const textureLoader = do {
#     new THREE.TextureLoader();
# };
#
# let trackball = makeTrackball();
# function makeTrackball() {
#     const trackball = do {
#         const camera_ = do {
#             camera.clone();
#         };
#         camera_.position.set(1.0, 0.0, 0.0);
#         camera_.up.set(0.0, -1.0, 0.0);
#         const domElement = renderer.domElement;
#         new TrackballControls(camera_, domElement);
#     };
#     trackball.target.set(0.0, 0.0, 0.0);
#     return trackball;
# };
#
# let recenter = makeRecenter();
# function makeRecenter() {
#     const recenter = do {
#         new RecenterCameraControls(renderer);
#     };
#     return recenter;
# };
#
# const recorder = new RecorderControls();
#
# renderer.xr.addEventListener('sessionstart', onsessionstart);
# renderer.xr.addEventListener('sessionend', onsessionend);
#
# const mesh = do {
#     const geometry = do {
#         const radius = 1.0;
#         const widthSegments = 60;
#         const heightSegments = 40;
#         new THREE.SphereGeometry(radius, widthSegments, heightSegments);
#     };
#     geometry.scale(-1.0, 1.0, 1.0); // make all faces point inwards
#     geometry.rotateY(Math.PI);
# //     geometry.rotateX(Math.PI);
#     const material = do {
#         const transparent = true;
#         const side = THREE.DoubleSide;
#         const map = do {
#             const position = [563.2271446178601, 3706.84551063691, -5153.367883611318]
#             const up = [563.2271446178601, 3706.84551063691, -5153.367883611318]
#             const direction = [3.3002321090438045, 0.29997060238702034, 1.1959763137756454]
#             const params = new URLSearchParams();
#             params.set('position', `${position}`);
#             params.set('up', `${up}`);
#             params.set('direction', `${direction}`);
#             const url = `api/v1/view/?${params}`;
#             textureLoader.load(url);
#         };
#         new THREE.MeshBasicMaterial({ transparent, side, map });
#     };
#     new THREE.Mesh(geometry, material);
# };
# scene.add(mesh);
#
# // setTimeout(oninterval, 5000);
# // async function oninterval() {
# //     console.log({ x: scene.position.x, y: scene.position.y, z: scene.position.z });
# //     console.log({ x: camera.position.x, y: camera.position.y, z: camera.position.z });
# //
# //     const position = [
# //         563.2271446178601 +  100 * (scene.position.x - camera.position.x),
# //         3706.84551063691 +   100 * (scene.position.y - camera.position.y),
# //         -5153.367883611318 + 100 * (scene.position.z - camera.position.z),
# //     ]
# //     const up = [
# //         563.2271446178601,
# //         3706.84551063691,
# //         -5153.367883611318,
# //     ]
# //     const direction = [
# //         3.3002321090438045,
# //         0.29997060238702034,
# //         1.1959763137756454,
# //     ]
# //     const params = new URLSearchParams();
# //     params.set('position', `${position}`);
# //     params.set('up', `${up}`);
# //     params.set('direction', `${direction}`);
# //     const url = `api/v1/view/?${params}`;
# //     const texture = await new Promise((resolve, reject) => {
# //         textureLoader.load(url, resolve, undefined, reject);
# //     });
# //     mesh.material.map = texture;
# //     mesh.material.needsUpdate = true;
# //
# //     setTimeout(oninterval, 5000);
# // }
#
# function onsessionstart() {
#     trackball.dispose();
#     trackball = null;
# }
#
# function onsessionend() {
#     trackball = makeTrackball();
# }
#
# function render() {
#     if (trackball !== null) {
#         trackball.update();
#         {
#             const src = trackball.object.position;
#             camera.lookAt(src.x, -src.y, src.z);
#         }
# //        {
# //            const src = trackball.object.up.clone();
# //            // src.multiplyScalar(-1.0);
# //            const dst = camera.up;
# //            dst.copy(src);
# //        }
#     }
#
# //     recorder.update(camera);
#     recenter.update(scene, camera);
#     renderer.render(scene, camera);
# }
#
# //=== Replay camera coordinates
#
# function ReplayerControls() {
#     const history = [];
#
#
#     return Object.assign(this, {
#         update,
#     })
#
#     function update(camera) {
#
#     }
#
#
#     //--- Utilities
#
#     function get() { //-> [ {now, position, up, direction}, ... ]
#
#     }
#
#     function now() { //-> milliseconds
#         return Date.now();
#     }
# }
#
# //=== Record camera coordinates
#
# function RecorderControls() {
#     const history = [];
#     const start = now();
#     let interval = setTimeout(oninterval, 5000);
#
#     return Object.assign(this, {
#         update,
#         dispose,
#     });
#
#     function update(camera) {
#         history.push({
#             now: now() - start,
#             position: position(camera),
#             up: up(camera),
#             direction: direction(camera),
#         });
#     }
#
#     function dispose() {
#         clearTimeout(interval);
#     }
#
#
#     //--- Event Handlers
#
#     async function oninterval() {
#         const body = {
#             history: [...history],
#         };
#         history.splice(0, history.length);
#
#         const response = await fetch('api/v1/history/', {
#             method: 'POST',
#             mode: 'cors',
#             body: JSON.stringify(body),
#         });
#         await response.text();
#
#         interval = setTimeout(oninterval, 5000);
#     }
#
#
#     //--- Utilities
#
#     function position(object) {
#         return {
#             x: camera.position.x,
#             y: camera.position.y,
#             z: camera.position.z,
#         };
#     }
#
#     function up(object) {
#         return {
#             x: camera.up.x,
#             y: camera.up.y,
#             z: camera.up.z,
#         };
#     }
#
#     function direction(object) {
#         const direction = new THREE.Vector3();
#         object.getWorldDirection(direction);
#         return {
#             x: direction.x,
#             y: direction.y,
#             z: direction.z,
#         };
#     }
#
#     function now() { //-> milliseconds
#         return Date.now();
#     }
# }
#
#
# //=== Let the user re-center the scene at the camera
#
# function RecenterCameraControls(renderer) {
#     let timeout = null;
#     let needsUpdate = false;
#     let controller = null;
#     renderer.domElement.addEventListener('pointerdown', onstart, true);
#     renderer.domElement.addEventListener('pointerup', onend, true);
#     renderer.xr.addEventListener('sessionstart', onsessionstart, true);
#     renderer.xr.addEventListener('sessionend', onsessionend, true);
#
#     return Object.assign(this, {
#         update,
#         dispose,
#     });
#
#
#     //--- Instance Methods
#
#     function update(scene, camera) {
#         if (needsUpdate) {
#             onupdate(scene, camera);
#             needsUpdate = false;
#         }
#     }
#
#     function dispose() {
#         renderer.domElement.removeEventListener('pointerdown', onstart, true);
#         renderer.domElement.removeEventListener('pointerup', onend, true);
#     }
#
#     function onlongtouch() {
#         needsUpdate = true;
#     }
#
#     function onshorttouch() {
#         //
#     }
#
#
#     //--- Event Listeners
#
#     function onsessionstart() {
#         controller = renderer.xr.getController(0);
#         controller.addEventListener('selectstart', onstart, true);
#         controller.addEventListener('selectend', onend, true);
#         controller.addEventListener('select', onlongtouch, true);
#     }
#
#     function onsessionend() {
#         controller.removeEventListener('selectstart', onstart, true);
#         controller.removeEventListener('selectend', onend, true);
#         controller.removeEventListener('select', onlongtouch, true);
#         controller = null;
#     }
#
#     function onupdate(scene, camera) {
#         console.group('RecenterCameraControls.onupdate');
#         console.log('scene.position', JSON.parse(JSON.stringify(scene.position)));
#         console.log('camera.position', JSON.parse(JSON.stringify(camera.position)));
#         scene.position.copy(camera.position);
#         console.groupEnd();
#     }
#
#     function onstart() {
#         timeout = setTimeout(ontimeout, 1000);
#     }
#
#     function onend() {
#         clearTimeout(timeout);
#         timeout = null;
#     }
#
#     function ontimeout() {
#         onlongtouch();
#     }
# }
#
# </script>

# %% [markdown]
# ## Run Server

# %%
@run(scope='service')
def __service(render, server, Animation, /):
    def now() -> auto.typing.Annotated[float, 'seconds']:
        return auto.time.clock_gettime(auto.time.CLOCK_MONOTONIC)
    
    def index(request: Request, /) -> Response:
        html = __index_html
        html = auto.string.Template(html)
        html = html.safe_substitute(
            THREE_VERSION='0.155.0',
        )
        
        return Response(
            status=200,
            content_type='text/html',
            data=html,
        )

    def panoramic(request: Request, /) -> Response:
        image = fetch((
            r"""https://cycling74-web-uploads.s3.amazonaws.com/"""
            r"""6187b6553cbf2d1585a07a79/2022-05-16T00:46:05Z/equirectangular_test_image.jpg"""
        ))
        
#         with auto.io.BytesIO() as f:
#             run.g['equi__image'].save(f, 'JPEG')
#             image = f.getvalue()
        
        return Response(
            status=200,
            content_type='image/jpg',
            data=image,
        )
    
    def view(request: Request, /, *, render, animation=None) -> Response:
        print(request.query)
        position = tuple(map(float, request.query['position'][0].split(',')))
        up = tuple(map(float, request.query['up'][0].split(',')))
        direction = tuple(map(float, request.query['direction'][0].split(',')))

        view = View(
            position=position,
            up=up,
            direction=direction,
        )
        
        when = auto.datetime.datetime(year=2023, month=6, day=1, hour=12, tzinfo=auto.datetime.timezone(
            auto.datetime.timedelta(hours=-5),
            name='EST',
        ))
        
        duration = now()

        image = render.send(Render(
            view=view,
            when=when,
        ))
        if animation is not None:
            thumb = image.copy()
            thumb.thumbnail((AW, AH))
            animation.send(thumb)

        with auto.io.BytesIO() as f:
            image.save(f, format='PNG')
            image = f.getvalue()

        duration = now() - duration
        print(f'{duration} sec/frame; {1./duration} frame/sec')

        return Response(
            status=200,
            content_type='image/png',
            data=image,
        )
    
    history = []
    with auto.contextlib.ExitStack() as stack:
        enter = stack.enter_context
        closing = auto.contextlib.closing
        
        enter( auto.contextlib.suppress(KeyboardInterrupt) )
        
        server = enter(closing( server(primary='sunrise') ))
        render = enter(closing( render(width=(RW := 2048), height=(RH := 2048), format='RGBA8') ))
        animation = enter(closing( Animation(width=(AW := 256), height=(AH := 256)) ))

        response = None
        while True:
            request = server.send(response)

            response = None
            if request.path == '/':
                response = index(request)
            
#             elif request.path == '/static/panoramic.jpg':
#                 response = panoramic(request)

            elif request.path == '/api/v1/view/':
                response = view(request, render=render, animation=animation)
        
            elif request.path == '/api/v1/history/':
                history.extend(auto.json.loads(request.body)['history'])
                response = Response(
                    status=200,
                    content_type='text/plain',
                    data=b'OK',
                )

            else:
                raise NotImplementedError(f'''Unexpected path: {request.path=!r}''')
    
#     auto.pprint.pprint(history)

# %%
# %%scope -o history
# def Decode(s: str) -> list[dict]:
#     s: bytes = s.encode('ascii')
#     s: bytes = auto.codecs.decode(s, 'base64')
#     s: list[dict] = auto.json.loads(s)
#     return s
#
# history = Decode(
# """W3siZGlyZWN0aW9uIjogeyJ4IjogMC43MjI3OTIxNDA3MDk5NTA4LCAieSI6IC0wLjMxNDYxMjM0
# NDk0MTc4ODQsICJ6IjogMC42MTUyOTcxNTg4OTAwNDA0fSwgIm5vdyI6IDE3Mzk1LCAicG9zaXRp
# b24iOiB7IngiOiAtMC4xNjk5MzQ5ODgwMjE4NTA1OSwgInkiOiAwLjA0MDgwMDY1MzM5ODAzNjk2
# LCAieiI6IC0wLjg1NDg5MDcwNDE1NDk2ODN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6Ijog
# MH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzM1MTgyMjgwNDc1NTY2NCwgInkiOiAtMC4zMjMx
# MDIyNzA5OTA3Mzk4NSwgInoiOiAwLjU5NTkxMjY5MjM5MzI1fSwgIm5vdyI6IDE3NDI2LCAicG9z
# aXRpb24iOiB7IngiOiAtMC4xNjkyOTc3OTk0NjgwNDA0NywgInkiOiAwLjA0MDgyNTU4MzA0MDcx
# NDI2NCwgInoiOiAtMC44NTYzMDAxMTU1ODUzMjcxfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAi
# eiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjc1MDI2NTI5OTU5NjcxMzgsICJ5IjogLTAu
# MzI0MjU1Mjk0ODgxMDk5OCwgInoiOiAwLjU3NjE2MDEyMDA3MzA3ODR9LCAibm93IjogMTc0NTgs
# ICJwb3NpdGlvbiI6IHsieCI6IC0wLjE2OTI2MTM2NjEyODkyMTUsICJ5IjogMC4wNDEzMzUyNDc0
# NTcwMjc0MzUsICJ6IjogLTAuODU3OTAyODI0ODc4NjkyNn0sICJ1cCI6IHsieCI6IDAsICJ5Ijog
# MSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43NjQ5Nzc2MzY4MTU4MDY1LCAieSI6
# IC0wLjMxOTk2NTI0ODU1NjYxMDMsICJ6IjogMC41NTg5NTU2ODI0MDA1MDE4fSwgIm5vdyI6IDE3
# NDk1LCAicG9zaXRpb24iOiB7IngiOiAtMC4xNjk2NDk3MzUwOTMxMTY3NiwgInkiOiAwLjA0MjIy
# MTE2NjE5MzQ4NTI2LCAieiI6IC0wLjg1OTc3ODgyMTQ2ODM1MzN9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzg1NDM5OTQ3ODY2MjgwMSwg
# InkiOiAtMC4zMTc3MDE5MzA2Njg0MzksICJ6IjogMC41MzExNzc1MzI5ODI0ODc1fSwgIm5vdyI6
# IDE3NTI1LCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzAxMDU5NjM5NDUzODg4LCAieSI6IDAuMDQz
# MjkyMzkyMDQ1MjU5NDc2LCAieiI6IC0wLjg2MjU0NTkwNzQ5NzQwNn0sICJ1cCI6IHsieCI6IDAs
# ICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44MDY1MzI2MzA0MjA2Njg2
# LCAieSI6IC0wLjMyMTExODQ0MTAzNzc2NzY1LCAieiI6IDAuNDk2Mzc0OTIxNjk5NTA2Nn0sICJu
# b3ciOiAxNzU1OSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTcwMzYwNDQ1OTc2MjU3MzIsICJ5Ijog
# MC4wNDQyNDA3MzE3NDU5NTgzMywgInoiOiAtMC44NjQ5NTkxODAzNTUwNzJ9LCAidXAiOiB7Ingi
# OiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODI2MDk4NTE0Njc4
# MzY0OCwgInkiOiAtMC4zMjM1NjAyNjIwMDM1NjAyNSwgInoiOiAwLjQ2MTM3ODM3MDY0NDI5Nzc2
# fSwgIm5vdyI6IDE3NTkyLCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzA4MzgyOTY0MTM0MjE2Mywg
# InkiOiAwLjA0NTMzMjgwODA0NzUzMzAzNSwgInoiOiAtMC44Njc0NTI1MDIyNTA2NzE0fSwgInVw
# IjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg0Mzcy
# NjA1ODkwNjI4NDUsICJ5IjogLTAuMzIzNzYzNTIwNTE2Nzk5MjQsICJ6IjogMC40MjgxMzk2MDM3
# NTY4MDgzfSwgIm5vdyI6IDE3NjMxLCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzE4MTQyOTI2Njky
# OTYyNiwgInkiOiAwLjA0NjQzOTY5NjEwMzMzNDQzLCAieiI6IC0wLjg3MDYyODUzNTc0NzUyODF9
# LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAu
# ODU2NzM2NzA1MzY3ODg2NiwgInkiOiAtMC4zMjU3NjY0MDY5NzQyMDY1NiwgInoiOiAwLjM5OTg0
# ODA1MzM0MzM4NTZ9LCAibm93IjogMTc2NTksICJwb3NpdGlvbiI6IHsieCI6IC0wLjE3MjQ0NDA2
# MDQ0NDgzMTg1LCAieSI6IDAuMDQ3NTI1NjcwMzc5NDAwMjUsICJ6IjogLTAuODczMzQ3OTM4MDYw
# NzYwNX0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4
# IjogMC44NjY1NDUxMzcwNjAxMjg4LCAieSI6IC0wLjMzMjgxNDYyNjM4OTY3OTksICJ6IjogMC4z
# NzE5MzI3MjIyNzQ1MjcyfSwgIm5vdyI6IDE3Njk1LCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzI1
# OTM5NTEyMjUyODA3NiwgInkiOiAwLjA0ODI3MDYwMTc3OTIyMjQ5LCAieiI6IC0wLjg3NTkyMTY2
# NjYyMjE2MTl9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6
# IHsieCI6IDAuODcxNjc0NDEwMzY5MjE0MSwgInkiOiAtMC4zMzg2Nzg5OTA4MTc1MzU2NiwgInoi
# OiAwLjM1NDIzMTkzNDU5NDEyNzZ9LCAibm93IjogMTc3MjcsICJwb3NpdGlvbiI6IHsieCI6IC0w
# LjE3MjM5NTAwNTgyMjE4MTcsICJ5IjogMC4wNDkwMzgyMzEzNzI4MzMyNSwgInoiOiAtMC44Nzg5
# NjU0Mzc0MTIyNjJ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlv
# biI6IHsieCI6IDAuODc2MTc4NDQ5OTIxNzIsICJ5IjogLTAuMzQ1NzAwOTEwNzg5ODgwMTMsICJ6
# IjogMC4zMzU4NjAzOTM4NzE5NDY5fSwgIm5vdyI6IDE3NzYwLCAicG9zaXRpb24iOiB7IngiOiAt
# MC4xNzIzMzIzNzYyNDE2ODM5NiwgInkiOiAwLjA0OTU1MTcxMDQ4NjQxMjA1LCAieiI6IC0wLjg4
# MTg4NDMzNjQ3MTU1NzZ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVj
# dGlvbiI6IHsieCI6IDAuODgwNzc0NzE1NjUxNjA2NCwgInkiOiAtMC4zNTQwMzkxMzE5Njk5MzM5
# LCAieiI6IDAuMzE0NDcxMjkxNjk4OTUyMDV9LCAibm93IjogMTc3OTUsICJwb3NpdGlvbiI6IHsi
# eCI6IC0wLjE3MjI2NzI3MzA2ODQyODA0LCAieSI6IDAuMDQ5OTg2NzcyMjM5MjA4MjIsICJ6Ijog
# LTAuODg0ODczMzMwNTkzMTA5MX0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsi
# ZGlyZWN0aW9uIjogeyJ4IjogMC44ODY2NjAwODQwNTMxMjExLCAieSI6IC0wLjM1NzUyNzMyOTk2
# NzI1NDA2LCAieiI6IDAuMjkzMjcxMzgyMjk1MzA0MzZ9LCAibm93IjogMTc4MjcsICJwb3NpdGlv
# biI6IHsieCI6IC0wLjE3Njg3NzQ2ODgyNDM4NjYsICJ5IjogMC4wNDc4MjQzOTAyMzI1NjMwMiwg
# InoiOiAtMC44ODg4MjMwMzIzNzkxNTA0fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9
# fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg5MTYyOTY5MDA2MzYzNzUsICJ5IjogLTAuMzU5NDcz
# NzM0ODA5NjU4NCwgInoiOiAwLjI3NTI3MjgyNzg5ODEwMDZ9LCAibm93IjogMTc4NjAsICJwb3Np
# dGlvbiI6IHsieCI6IC0wLjE3NzY2MjU2NjMwNDIwNjg1LCAieSI6IDAuMDQ4MTgwMDYyMzIzODA4
# NjcsICJ6IjogLTAuODkyNTA2MjQxNzk4NDAwOX0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoi
# OiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44OTU0MTg2ODM0MzY3MDM2LCAieSI6IC0wLjM1
# NzA1NTkwODgwMDIxMDY1LCAieiI6IDAuMjY1OTYzMjY2OTA2MDQ0NTV9LCAibm93IjogMTc4OTYs
# ICJwb3NpdGlvbiI6IHsieCI6IC0wLjE3ODY3NDYyMzM3MDE3MDYsICJ5IjogMC4wNDg2OTUzNzgw
# MDU1MDQ2MSwgInoiOiAtMC44OTYwNzg5NDQyMDYyMzc4fSwgInVwIjogeyJ4IjogMCwgInkiOiAx
# LCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg5OTc3MjY3NDQxNDM4NzUsICJ5Ijog
# LTAuMzUzNjM4OTcwMTc2Mzc5NDYsICJ6IjogMC4yNTU2MzM3NDgwNjUwMjA4fSwgIm5vdyI6IDE3
# OTI2LCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzg1MjM5NzI2MzA1MDA4LCAieSI6IDAuMDQxMTgy
# MDgyMTQ2NDA2MTc0LCAieiI6IC0wLjg5MzEwMzc3ODM2MjI3NDJ9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuOTA0ODA0OTA4NDc1NTEzNCwg
# InkiOiAtMC4zNTY0MDgyMTcyODIwNjc1LCAieiI6IDAuMjMzMDI2MzA4MDY5MzYwNH0sICJub3ci
# OiAxNzk2MSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTc5NTkzMjc5OTU3NzcxMywgInkiOiAwLjA0
# MTA0MzY5NTA2MjM5ODkxLCAieiI6IC0wLjg5NjY2MzYwNjE2NjgzOTZ9LCAidXAiOiB7IngiOiAw
# LCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuOTA5Nzk5OTg0MjQ5Mjk1
# NSwgInkiOiAtMC4zNjM3NTI1MTMyODcxNzkyLCAieiI6IDAuMTk5ODcwMjAyMjI0NDQ5OH0sICJu
# b3ciOiAxNzk5MywgInBvc2l0aW9uIjogeyJ4IjogLTAuMTgwNDI5Njk3MDM2NzQzMTYsICJ5Ijog
# MC4wNDA2Mzg5OTA3MDAyNDQ5MDQsICJ6IjogLTAuOTAwNDAzNDk5NjAzMjcxNX0sICJ1cCI6IHsi
# eCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC45MTM0MjI0MjE2
# NDQ2MTE3LCAieSI6IC0wLjM2ODU3ODM3MjIzNzIwMDcsICJ6IjogMC4xNzI2NTQxNzIxMzU3MTMz
# OH0sICJub3ciOiAxODAyOCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTc0NTM1NjMyMTMzNDgzOSwg
# InkiOiAwLjAzMTc0NTYyMDA3MTg4Nzk3LCAieiI6IC0wLjg5NjEyMzA1MTY0MzM3MTZ9LCAidXAi
# OiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuOTE2OTg1
# MDc1MDYyMTY5NCwgInkiOiAtMC4zNjgzNjQ4MTc2NDcwMTI4NCwgInoiOiAwLjE1MzExOTk5NjE4
# OTYyMjcxfSwgIm5vdyI6IDE4MDYyLCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzU5ODU2OTM5MzE1
# Nzk2LCAieSI6IDAuMDMxMzA0OTQ4MDMxOTAyMzEsICJ6IjogLTAuOTAwMDI5NDIwODUyNjYxMX0s
# ICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC45
# MTk4MjA5MTIwODMyODcsICJ5IjogLTAuMzY4ODM3Njg5ODk0OTMzNzYsICJ6IjogMC4xMzM3NDY5
# NTU4ODAyNjk0N30sICJub3ciOiAxODA5NiwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTc3NDg5MTAx
# ODg2NzQ5MjcsICJ5IjogMC4wMzA5NzI4OTI0MTg1MDM3NiwgInoiOiAtMC45MDM4ODk1OTY0NjIy
# NDk4fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7Ingi
# OiAwLjkyMjczNTA4ODY2MjU4MzcsICJ5IjogLTAuMzY4NTEwNTM3MTYxODAxNSwgInoiOiAwLjEx
# Mjk1OTkwNTA2MTgxNjA1fSwgIm5vdyI6IDE4MTI5LCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzkw
# NzI0MDk4NjgyNDAzNiwgInkiOiAwLjAzMDY1ODkzMjQwMjcyOTk4OCwgInoiOiAtMC45MDc3NDg0
# NjA3Njk2NTMzfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24i
# OiB7IngiOiAwLjkyNDA4NzY3ODEyMDA1MDIsICJ5IjogLTAuMzcxMDQ5MDQ2NTgwMzMyNDQsICJ6
# IjogMC4wOTE1NjcyODc3MDk3NTMzMn0sICJub3ciOiAxODE2NCwgInBvc2l0aW9uIjogeyJ4Ijog
# LTAuMTc0ODIzODY1Mjk0NDU2NDgsICJ5IjogMC4wMjU0MzgzNTUyODE5NDkwNDMsICJ6IjogLTAu
# OTA5NDI1Mzc3ODQ1NzY0Mn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGly
# ZWN0aW9uIjogeyJ4IjogMC45MjM4MTUxOTY1MTg3MTkxLCAieSI6IC0wLjM3NTE0Mjk2NjAxMjg2
# NTIzLCAieiI6IDAuMDc2Mzc1NjM1NzIzMzgwMDl9LCAibm93IjogMTgxOTYsICJwb3NpdGlvbiI6
# IHsieCI6IC0wLjE3NTgwMzA2NTI5OTk4NzgsICJ5IjogMC4wMjQ1NDY2MDA4NzgyMzg2NzgsICJ6
# IjogLTAuOTEyOTM3NTgxNTM5MTU0fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwg
# eyJkaXJlY3Rpb24iOiB7IngiOiAwLjkyNDEzNDgwOTI3MTQxMDksICJ5IjogLTAuMzc2MTI5NjMw
# MjY1NjMzNSwgInoiOiAwLjA2NzA5MjE0MjA4MTg0NzV9LCAibm93IjogMTgyMzAsICJwb3NpdGlv
# biI6IHsieCI6IC0wLjE3NjAyNDI4NzkzOTA3MTY2LCAieSI6IDAuMDIzNjQ5MzIwMDA2MzcwNTQ0
# LCAieiI6IC0wLjkxNDgzMDIwNzgyNDcwN30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAw
# fX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC45MjU1NzIxMjkyNDQ3NDY5LCAieSI6IC0wLjM3NDA4
# NDY4MTgxNTU4Mjk2LCAieiI6IDAuMDU4MTEwOTY2MjMwODIzMTF9LCAibm93IjogMTgyODIsICJw
# b3NpdGlvbiI6IHsieCI6IC0wLjE3NzU4OTE2MzE4NDE2NTk1LCAieSI6IDAuMDIyOTc2MDIyMjEz
# Njk3NDMzLCAieiI6IC0wLjkxODI2NjI5NjM4NjcxODh9LCAidXAiOiB7IngiOiAwLCAieSI6IDEs
# ICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuOTI1OTM2OTUzNDk3OTU3MywgInkiOiAt
# MC4zNzQ1MTAzNDg5MTIzMTM4MywgInoiOiAwLjA0ODgxMzQ4ODk2MDUxODkxN30sICJub3ciOiAx
# ODI5NSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTc4OTU4MDI4NTU0OTE2MzgsICJ5IjogMC4wMjIy
# NDg0ODc5MTk1NjkwMTYsICJ6IjogLTAuOTIxNjA5MDQ0MDc1MDEyMn0sICJ1cCI6IHsieCI6IDAs
# ICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC45MjQ4MzU4MTk3MDg4MjQs
# ICJ5IjogLTAuMzc5MDY0NjU3ODY4NTc3MSwgInoiOiAwLjAzMTQ0MzQ2ODkzMjEzMjg3fSwgIm5v
# dyI6IDE4MzMxLCAicG9zaXRpb24iOiB7IngiOiAtMC4xODAwNTkwNDU1NTMyMDc0LCAieSI6IDAu
# MDIxNDE4MzIwMDE1MDcyODIzLCAieiI6IC0wLjkyNDgyMjY4ODEwMjcyMjJ9LCAidXAiOiB7Ingi
# OiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuOTIyODcwMzQ5NzUx
# ODYyNCwgInkiOiAtMC4zODQ4MjYyMzc2MjY4NDg3NiwgInoiOiAwLjAxNDgwMTQ5OTM0NDI5NzI0
# NH0sICJub3ciOiAxODM2NSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTc5NTQ1MDg5NjAyNDcwNCwg
# InkiOiAwLjAyMzcxMDM3NTY1MTcxNzE4NiwgInoiOiAtMC45MjE2MTc3NDYzNTMxNDk0fSwgInVw
# IjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjkyMTkw
# Nzk4MDUxOTM3MjMsICJ5IjogLTAuMzg3NDA3OTI3MTk1MzYzOSwgInoiOiAwLjAwMDg3OTQzMjEz
# NzQwNzk3MzF9LCAibm93IjogMTgzOTYsICJwb3NpdGlvbiI6IHsieCI6IC0wLjE4MDcxMzQxNTE0
# NTg3NDAyLCAieSI6IDAuMDIzMzA1NDgxMjk5NzU3OTU3LCAieiI6IC0wLjkyNDkyNzE3NTA0NTAx
# MzR9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6
# IDAuOTE5ODAyNjY4ODMzMjc4OSwgInkiOiAtMC4zOTE5NDY0MTQyODU1OTM0LCAieiI6IC0wLjAx
# ODQ2Nzc3NTYwNjI3NDQxfSwgIm5vdyI6IDE4NDMyLCAicG9zaXRpb24iOiB7IngiOiAtMC4xNzk1
# MDM0MjU5NTU3NzI0LCAieSI6IDAuMDIyNjgyMzMzMzY1MDgyNzQsICJ6IjogLTAuOTI2NjQ2NzA5
# NDQyMTM4N30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjog
# eyJ4IjogMC45MTY3NTM1ODk4MDkxNzQsICJ5IjogLTAuMzk3MjA2NDI0NjU5NzM1NSwgInoiOiAt
# MC4wNDIzMDczNDkwMTkwODc0N30sICJub3ciOiAxODQ2NSwgInBvc2l0aW9uIjogeyJ4IjogLTAu
# MTgwNTkwNDM1ODYyNTQxMiwgInkiOiAwLjAyMjA4NjY3OTkzNTQ1NTMyMiwgInoiOiAtMC45MzAz
# NzQwMjYyOTg1MjN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlv
# biI6IHsieCI6IDAuOTE0MDMwOTI2NjI3NTgwMiwgInkiOiAtMC40MDA1MjQ4NDAxMjk0ODg3NSwg
# InoiOiAtMC4wNjQyNDQyMDI5MTAyNTgzMX0sICJub3ciOiAxODUwMCwgInBvc2l0aW9uIjogeyJ4
# IjogLTAuMTgxNzQ4NTU0MTEwNTI3MDQsICJ5IjogMC4wMjE1MDQzNDQ0MTg2NDQ5MDUsICJ6Ijog
# LTAuOTM0MjkxNzc5OTk0OTY0Nn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsi
# ZGlyZWN0aW9uIjogeyJ4IjogMC45MTA1NzI3MDMxMTQ3OTg0LCAieSI6IC0wLjQwNDc2NDkzODEy
# NzM4OTA2LCAieiI6IC0wLjA4MzgwMTUzNDYyMTYyOTU0fSwgIm5vdyI6IDE4NTMxLCAicG9zaXRp
# b24iOiB7IngiOiAtMC4xODIwMTM3NTAwNzYyOTM5NSwgInkiOiAwLjAyMzc2MjcxOTcwNTcwMDg3
# NCwgInoiOiAtMC45MzU4MTU1NzI3Mzg2NDc1fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6
# IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjkwNDEzNDk5OTI3ODc5MjMsICJ5IjogLTAuNDEy
# Mjc3MjQ4NDg3NTE0MywgInoiOiAtMC4xMTIxMDQyOTcyMzU2NjYzM30sICJub3ciOiAxODU2Nywg
# InBvc2l0aW9uIjogeyJ4IjogLTAuMTgyOTg0MjMyOTAyNTI2ODYsICJ5IjogMC4wMjMwNjM2ODIw
# MTk3MTA1NCwgInoiOiAtMC45NDA4MzIxOTc2NjYxNjgyfSwgInVwIjogeyJ4IjogMCwgInkiOiAx
# LCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjkwMDEwOTc0OTYyNDI4NTcsICJ5Ijog
# LTAuNDE0NDk0OTU2NjI1MDEyMjMsICJ6IjogLTAuMTM0MTUwNTQ4MTMwNTgwNDd9LCAibm93Ijog
# MTg2MDEsICJwb3NpdGlvbiI6IHsieCI6IC0wLjE4NDYzNjU5Mjg2NDk5MDIzLCAieSI6IDAuMDIy
# NTYwMTAxMDAyNDU0NzU4LCAieiI6IC0wLjk0NTgzMzg2MTgyNzg1MDN9LCAidXAiOiB7IngiOiAw
# LCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuOTAwMDYxOTkwMDE3NTAx
# MywgInkiOiAtMC40MDk0ODM1Mjk5MTQxNTc2NSwgInoiOiAtMC4xNDkwMzU3NDM1NDc1Njg4fSwg
# Im5vdyI6IDE4NjM1LCAicG9zaXRpb24iOiB7IngiOiAtMC4xODM5NjQwMTQwNTMzNDQ3MywgInki
# OiAwLjAyMTMxNDAzOTgyNjM5MzEyNywgInoiOiAtMC45NDQ5NDk1MDc3MTMzMTc5fSwgInVwIjog
# eyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg5NjU2ODMw
# OTgxODI4NDIsICJ5IjogLTAuNDA4NTk1NzM0OTE5NjI5MywgInoiOiAtMC4xNzA5MjMzNDkwMDQ5
# NjYwOX0sICJub3ciOiAxODY2NSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTg1OTc2Nzg4NDAxNjAz
# NywgInkiOiAwLjAyMDg2NjQ3MjI3NDA2NTAxOCwgInoiOiAtMC45NDkzNjU3MzUwNTQwMTYxfSwg
# InVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg5
# NDE4OTE4ODI3NjU1ODksICJ5IjogLTAuNDA3NjQwMTkxOTkzNTgxOCwgInoiOiAtMC4xODUwODE1
# MjEwNjc3Mjg2OH0sICJub3ciOiAxODcwMCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTg3Njg0OTIz
# NDEwNDE1NjUsICJ5IjogMC4wMjA1MDE0MzEwNzc3MTg3MzUsICJ6IjogLTAuOTUzMjM2NDAxMDgx
# MDg1Mn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4
# IjogMC44OTQyNTY1NzU5MzU1MDQyLCAieSI6IC0wLjQwNDQ0ODQ3OTgwODg0NTQsICJ6IjogLTAu
# MTkxNjQxODYyNzk3MzA2NX0sICJub3ciOiAxODczOCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTg4
# ODQ5MDkxNTI5ODQ2MiwgInkiOiAwLjAyMDM4MTkyMTkwMjI5ODkyNywgInoiOiAtMC45NTE4NTgy
# MjI0ODQ1ODg2fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24i
# OiB7IngiOiAwLjg5MjE0MzY4MzI3NDM0ODYsICJ5IjogLTAuNDAzNzcxNzM2NzQzMjc1OCwgInoi
# OiAtMC4yMDI2MDMxNDE2MzY1NDQ0fSwgIm5vdyI6IDE4NzY4LCAicG9zaXRpb24iOiB7IngiOiAt
# MC4xOTAzMDU4ODg2NTI4MDE1LCAieSI6IDAuMDIwMTI2MTQzNDcwNDA2NTMyLCAieiI6IC0wLjk1
# NTI4NTkwNjc5MTY4N30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0
# aW9uIjogeyJ4IjogMC44ODkyMTU0MzY4MTg4Nzc4LCAieSI6IC0wLjQwNDU1NzM0MzcxMjcyMTIz
# LCAieiI6IC0wLjIxMzYxMDA3MTMyNDE3NjI1fSwgIm5vdyI6IDE4ODAyLCAicG9zaXRpb24iOiB7
# IngiOiAtMC4xOTEzNjg1MDUzNTg2OTU5OCwgInkiOiAwLjAxOTgyNzY1MjcyMjU5NzEyMiwgInoi
# OiAtMC45NTg0NDg0Njk2Mzg4MjQ1fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwg
# eyJkaXJlY3Rpb24iOiB7IngiOiAwLjg4NjEwODYxNjUwNzM5NTcsICJ5IjogLTAuNDA2OTM3NDUy
# NTM1MDYzNywgInoiOiAtMC4yMjE4NDEwMDA0Mzg2NTEzOH0sICJub3ciOiAxODgzNSwgInBvc2l0
# aW9uIjogeyJ4IjogLTAuMTkwOTY2MDY5Njk4MzMzNzQsICJ5IjogMC4wMTkxMDY5MjA4MDg1NTM2
# OTYsICJ6IjogLTAuOTU0MDkzMzM3MDU5MDIxfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6
# IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg4MzI0OTI4NjA2OTQzMDEsICJ5IjogLTAuNDA4
# NTQ4OTk3NjEzODQ4NjYsICJ6IjogLTAuMjMwMTI2OTU0NTQxNTM0ODR9LCAibm93IjogMTg4ODEs
# ICJwb3NpdGlvbiI6IHsieCI6IC0wLjE5MTkxMTYyMjg4MTg4OTM0LCAieSI6IDAuMDE4ODA5NDMw
# MzAxMTg5NDIzLCAieiI6IC0wLjk1NjkxNDI0NjA4MjMwNTl9LCAidXAiOiB7IngiOiAwLCAieSI6
# IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODc4NzQyMzk0NzU2ODc0LCAieSI6
# IC0wLjQwOTk5ODUxMjc5NzM4MiwgInoiOiAtMC4yNDQzNjI0ODMxMjg4MzMzNX0sICJub3ciOiAx
# ODkxMiwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTkzMDc1MTA1NTQ3OTA0OTcsICJ5IjogMC4wMTg1
# MDE1NDI1MDg2MDIxNDIsICJ6IjogLTAuOTU5OTQ3NDA3MjQ1NjM2fSwgInVwIjogeyJ4IjogMCwg
# InkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg3MjI5Njc2NjYzMDE3NDQs
# ICJ5IjogLTAuNDEzNzY5NDcwMDUwMTc3OCwgInoiOiAtMC4yNjA1NjMxOTExNDc0NDEzNn0sICJu
# b3ciOiAxODk0NSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMTkxMjg5MjAxMzc4ODIyMzMsICJ5Ijog
# MC4wMjQ2OTA2MjYxODkxMTI2NjMsICJ6IjogLTAuOTQ1NTA0MjQ4MTQyMjQyNH0sICJ1cCI6IHsi
# eCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44Njg4MzUzNTgy
# NzA1MiwgInkiOiAtMC40MTI4NTU2NjM0MDg5OTkyLCAieiI6IC0wLjI3MzI2Nzg1NjUyNTUxOTd9
# LCAibm93IjogMTg5NzcsICJwb3NpdGlvbiI6IHsieCI6IC0wLjE5MjkyNDg4Njk0MTkwOTgsICJ5
# IjogMC4wMjQ5MDQ2ODMyMzIzMDc0MzQsICJ6IjogLTAuOTQ3Njk2NDQ3MzcyNDM2NX0sICJ1cCI6
# IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44NjUzMDU1
# NzUwNzU1MzAxLCAieSI6IC0wLjQwOTk0MjI2NzMyNDMxNzgsICJ6IjogLTAuMjg4NDMzMDA2NDQw
# MzIzMDV9LCAibm93IjogMTkwMDksICJwb3NpdGlvbiI6IHsieCI6IC0wLjE5NDg0ODk4NDQ3OTkw
# NDE3LCAieSI6IDAuMDI1MTc5Njk5MDYzMzAxMDg2LCAieiI6IC0wLjk0OTk3NDc3NTMxNDMzMX0s
# ICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44
# NTg5ODA2ODQyODcyMjcsICJ5IjogLTAuNDA4NzMxNzc4NDUwMzc5NSwgInoiOiAtMC4zMDgzNjc1
# MDM2NDgyMjR9LCAibm93IjogMTkwNDUsICJwb3NpdGlvbiI6IHsieCI6IC0wLjE5ODAwMzc1NDAx
# OTczNzI0LCAieSI6IDAuMDI2MDgyNjQ5ODI3MDAzNDgsICJ6IjogLTAuOTUwNzkxNDE4NTUyMzk4
# N30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4Ijog
# MC44NTQ4NzczMjczOTU1ODY1LCAieSI6IC0wLjQwODQyMTcyNjc2NTQ3MzgsICJ6IjogLTAuMzE5
# OTYzMTk4MjEzMzA2NH0sICJub3ciOiAxOTA3OCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjAwMDc4
# NjM2NDA3ODUyMTcsICJ5IjogMC4wMjYxNjYxODk0NjE5NDY0ODcsICJ6IjogLTAuOTUzMzMwMzk3
# NjA1ODk2fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7
# IngiOiAwLjg1MTYxMTYyNTM1NDAyNjgsICJ5IjogLTAuNDEwNzk5NzA4MzA1OTMxLCAieiI6IC0w
# LjMyNTU3ODMxNTAyOTc4NjN9LCAibm93IjogMTkxMDMsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIw
# MTU5NzU0MTU3MDY2MzQ1LCAieSI6IDAuMDI2MTE0NDc0OTgyMDIzMjQsICJ6IjogLTAuOTU1Nzk2
# NDIwNTc0MTg4Mn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9u
# IjogeyJ4IjogMC44NDUxNzYwNDYxMjgxNzksICJ5IjogLTAuNDEzNTk3NDE3NDQxNzEzMywgInoi
# OiAtMC4zMzg1NDc4MjEzNDM4NzQwN30sICJub3ciOiAxOTEzOSwgInBvc2l0aW9uIjogeyJ4Ijog
# LTAuMjAzMjQwOTc1NzM3NTcxNzIsICJ5IjogMC4wMjYyOTk3NjE2MDgyNDI5OSwgInoiOiAtMC45
# NTczNjkzMjc1NDUxNjZ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVj
# dGlvbiI6IHsieCI6IDAuODQwMzIwMTI2MDQ2MTM3LCAieSI6IC0wLjQxNjM3MzE5NDI5ODQxOTM1
# LCAieiI6IC0wLjM0NzEyNDU0MzY4OTM0MzUzfSwgIm5vdyI6IDE5MTcxLCAicG9zaXRpb24iOiB7
# IngiOiAtMC4yMDQ1ODg0MTMyMzg1MjU0LCAieSI6IDAuMDI2MjE2MzQxMTgyNTg5NTMsICJ6Ijog
# LTAuOTU5NTM4NTc4OTg3MTIxNn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsi
# ZGlyZWN0aW9uIjogeyJ4IjogMC44MzgyNDQ3NDY4ODA0OCwgInkiOiAtMC40MTczMTI2NDAzNDQx
# Nzg1LCAieiI6IC0wLjM1MDk5Mjc0MTQyOTU3NzU0fSwgIm5vdyI6IDE5MjA0LCAicG9zaXRpb24i
# OiB7IngiOiAtMC4yMDU3MTIxOTkyMTExMjA2LCAieSI6IDAuMDI2Mjc4NTIxODY1NjA2MzA4LCAi
# eiI6IC0wLjk2MTM1NDMxNTI4MDkxNDN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19
# LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODM1MzQ2NDAwODgxNjEzMiwgInkiOiAtMC40MTc0Mzg1
# NjA2ODEwNDk3LCAieiI6IC0wLjM1NzY4OTAyNDk3OTMzNzQ3fSwgIm5vdyI6IDE5MjM5LCAicG9z
# aXRpb24iOiB7IngiOiAtMC4yMDcyMTU1NzczNjM5Njc5LCAieSI6IDAuMDI1ODkyNTU5NDM4OTQz
# ODYzLCAieiI6IC0wLjk2MzYyOTAwNzMzOTQ3NzV9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6
# IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODMzMzExMzY4MzQ1ODA3LCAieSI6IC0wLjQx
# NjAyMDU0NTI4MDM3MjI0LCAieiI6IC0wLjM2NDAzMTY4NzIwNjI5MzUzfSwgIm5vdyI6IDE5MjY3
# LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMDg3NzUxOTI0OTkxNjA3NywgInkiOiAwLjAyNTkyNDYw
# MDY2MDgwMDkzNCwgInoiOiAtMC45NjU2ODYwODI4Mzk5NjU4fSwgInVwIjogeyJ4IjogMCwgInki
# OiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjgzMDM0Njk0MDAzODY0MDQsICJ5
# IjogLTAuNDE0NzA5NDc2MzgyMzk0NSwgInoiOiAtMC4zNzIyMDk2MzA5NDM1MTM2N30sICJub3ci
# OiAxOTMwMCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjEwMzk2ODU2MDY5NTY0ODIsICJ5IjogMC4w
# MjU4NjgxMzI3MTA0NTY4NDgsICJ6IjogLTAuOTY3OTMxNzQ3NDM2NTIzNH0sICJ1cCI6IHsieCI6
# IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44MjMxODIyNDMyOTI0
# MDc0LCAieSI6IC0wLjQxNTYxOTg5MzEwNTY4MTI2LCAieiI6IC0wLjM4NjgyMTc5MjAyMTcyODd9
# LCAibm93IjogMTkzMzQsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIxMTk5ODA0NTQ0NDQ4ODUzLCAi
# eSI6IDAuMDI1NjI2MTgwNjkzNTA3MTk1LCAieiI6IC0wLjk3MDQwNjUzMjI4NzU5Nzd9LCAidXAi
# OiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODE1NzQ1
# NzEyNjI3NjQ2OCwgInkiOiAtMC40MTgyMjQ4ODk3NzUyMjYzLCAieiI6IC0wLjM5OTU1ODM0ODU1
# NzY0NDU1fSwgIm5vdyI6IDE5MzY5LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMTM2OTI4NDM5MTQw
# MzE5OCwgInkiOiAwLjAyNTI1NTk4NTU1ODAzMjk5LCAieiI6IC0wLjk3Mjc1NDEyMDgyNjcyMTJ9
# LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAu
# ODExNDg2NDcxNjA0MDY1OCwgInkiOiAtMC40MTgyNTE1OTQxOTgwNTg2MywgInoiOiAtMC40MDgx
# MTE4ODQ2MDMxODg0fSwgIm5vdyI6IDE5NDA0LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMTUzNzM1
# MzA5ODM5MjQ4NywgInkiOiAwLjAyNTAwODExNzc4MDA4OTM4LCAieiI6IC0wLjk3NDgxNDQxNDk3
# ODAyNzN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsi
# eCI6IDAuODAzMzUyMDY5NDc4MDk0MywgInkiOiAtMC40MTkwNjI1MjMyNTk1NDM5NiwgInoiOiAt
# MC40MjMwOTgxNjEyNjM1NjIxNH0sICJub3ciOiAxOTQzOCwgInBvc2l0aW9uIjogeyJ4IjogLTAu
# MjE3MzU3MDk5MDU2MjQzOSwgInkiOiAwLjAyNDkyODk1MzQ5ODYwMTkxMywgInoiOiAtMC45NzY4
# NTMyNTE0NTcyMTQ0fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rp
# b24iOiB7IngiOiAwLjc5MTY4MjQ3NTQyMDIzMTIsICJ5IjogLTAuNDIwODM1NTkzNzEwMTcwMiwg
# InoiOiAtMC40NDI4NzI3MzcwMDEzOTE3fSwgIm5vdyI6IDE5NDY4LCAicG9zaXRpb24iOiB7Ingi
# OiAtMC4yMTkzMzI4ODg3MjI0MTk3NCwgInkiOiAwLjAyNDQ0Mjk1MDI2MzYxOTQyMywgInoiOiAt
# MC45Nzg5OTMyMzcwMTg1ODUyfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJk
# aXJlY3Rpb24iOiB7IngiOiAwLjc4NjUxNTIyNTExNzMxNzMsICJ5IjogLTAuNDIwMjM2MjkxMzk1
# NzIyNywgInoiOiAtMC40NTI1NDMxMDI5Nzc2MzM1fSwgIm5vdyI6IDE5NTA2LCAicG9zaXRpb24i
# OiB7IngiOiAtMC4yMjEwMDE5Njc3ODc3NDI2MSwgInkiOiAwLjAyNDA3NjM3Nzk3Mjk2MDQ3Miwg
# InoiOiAtMC45ODA3ODI4MDY4NzMzMjE1fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9
# fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjc4MzY1ODU2MTIyNjUwMjUsICJ5IjogLTAuNDE5OTky
# MzU3MzA0MzM4MiwgInoiOiAtMC40NTc2OTYwNTU1MDIyODc1NH0sICJub3ciOiAxOTU0MSwgInBv
# c2l0aW9uIjogeyJ4IjogLTAuMjIyMjM4MjcyNDI4NTEyNTcsICJ5IjogMC4wMjM3MTQxODEwMzU3
# NTcwNjUsICJ6IjogLTAuOTgyMzc2Njk0Njc5MjYwM30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwg
# InoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43NzkzNzU0OTY5MTk4NjczLCAieSI6IC0w
# LjQxOTQ5NjEyNjg0MTIzMDEsICJ6IjogLTAuNDY1Mzk5NjUwMTU2ODQ4fSwgIm5vdyI6IDE5NTc0
# LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjQwNzUzNDcxODUxMzQ5LCAieSI6IDAuMDIzMjc4OTIx
# ODQyNTc1MDczLCAieiI6IC0wLjk4NDAwODc4OTA2MjV9LCAidXAiOiB7IngiOiAwLCAieSI6IDEs
# ICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzc0MDE4Mzc3MDg4MDA4MiwgInkiOiAt
# MC40MTg0MzM1ODY5NDY1NjE1LCAieiI6IC0wLjQ3NTE5MzUyMzk5MzIwNDM2fSwgIm5vdyI6IDE5
# NjAzLCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjU2OTE3NTA2NDU2Mzc1LCAieSI6IDAuMDIzMDE1
# MTYzODM4ODYzMzczLCAieiI6IC0wLjk4NTU2ODU4MzAxMTYyNzJ9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzY5NDUwMTU3NDc4NjkyOSwg
# InkiOiAtMC40MTcyMTg5MjIwMDQyNjUyLCAieiI6IC0wLjQ4MzYwNjA2NTE3ODY4ODI2fSwgIm5v
# dyI6IDE5NjQxLCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjc2Mjk5NTk1ODMyODI0NywgInkiOiAw
# LjAyMzEwMTkwNTM2MDgxNzkxLCAieiI6IC0wLjk4NzA1MjIwMjIyNDczMTR9LCAidXAiOiB7Ingi
# OiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzY1MTUwNzM4NDM1
# OTgzNCwgInkiOiAtMC40MTU4MDE4Mjg4ODE0NDE2LCAieiI6IC0wLjQ5MTU4MjMyOTM5MTIzOTc1
# fSwgIm5vdyI6IDE5NjcyLCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjkxMTM0NTk1ODcwOTcxNywg
# InkiOiAwLjAyMzE1ODczMjgwMTY3NTc5NywgInoiOiAtMC45ODgwNTgyMDk0MTkyNTA1fSwgInVw
# IjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjc2MDA3
# NzA2OTAxOTkzMTIsICJ5IjogLTAuNDE0MDYyNTAzNzY0ODA3OSwgInoiOiAtMC41MDA4MzQzOTU5
# MDk1NTU2fSwgIm5vdyI6IDE5NzA1LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMzA1MTgyODE0NTk4
# MDgzNSwgInkiOiAwLjAyMzE5MDc2NjU3Mjk1MjI3LCAieiI6IC0wLjk4ODk5NzYzODIyNTU1NTR9
# LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAu
# NzUzMjg0MzAyMzY4ODAzNSwgInkiOiAtMC40MTM4NzQ2MzY4NzQyMzU5LCAieiI6IC0wLjUxMTE0
# NjMwNDY0OTYyMjN9LCAibm93IjogMTk3MzksICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMTYyMzAy
# Mzc0ODM5NzgzLCAieSI6IDAuMDIzMDk5NzIwNDc4MDU3ODYsICJ6IjogLTAuOTg5OTA3NjgxOTQx
# OTg2MX0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4
# IjogMC43NDg3NTgyMjc4Mjc1MjgzLCAieSI6IC0wLjQxNDQ1MjE5NTk2OTYxMDcsICJ6IjogLTAu
# NTE3MjkxNDk3NjI2MzgzNH0sICJub3ciOiAxOTc3MiwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjMy
# NDkzNjgzNjk1NzkzMTUsICJ5IjogMC4wMjMyNDA1MTU5NjIyNDMwOCwgInoiOiAtMC45ODk3NDgx
# Nzk5MTI1NjcxfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24i
# OiB7IngiOiAwLjczODEzMTEwMjE1NTk3OTUsICJ5IjogLTAuNDE2NjIzNjUyNjQ1Nzc5MzMsICJ6
# IjogLTAuNTMwNjQ3OTEzNDg1MDk3OX0sICJub3ciOiAxOTgwNSwgInBvc2l0aW9uIjogeyJ4Ijog
# LTAuMjMzMzc3MzM3NDU1NzQ5NSwgInkiOiAwLjAyMjk5MjU3MTgxNTg0ODM1LCAieiI6IC0wLjk5
# MDU2MDIzMzU5Mjk4NzF9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVj
# dGlvbiI6IHsieCI6IDAuNzI2NjE0NzIyOTYwNzE3LCAieSI6IC0wLjQxODU0NDQzNzM1NzQyMDI1
# LCAieiI6IC0wLjU0NDg0MDg5MjY3Nzc0Mzh9LCAibm93IjogMTk4NTMsICJwb3NpdGlvbiI6IHsi
# eCI6IC0wLjIzNDE5Mjk2NzQxNDg1NTk2LCAieSI6IDAuMDIyMzk4MTIxNjU0OTg3MzM1LCAieiI6
# IC0wLjk5MDUxNTcwODkyMzMzOTh9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7
# ImRpcmVjdGlvbiI6IHsieCI6IDAuNzIwOTYwMTUwNTQ0NDQzNCwgInkiOiAtMC40MjAzOTA0OTE1
# NTY5NjI5NSwgInoiOiAtMC41NTA4OTc3MTgyMTU4NDg4fSwgIm5vdyI6IDE5ODc0LCAicG9zaXRp
# b24iOiB7IngiOiAtMC4yMzQ1NDM1NDcwMzQyNjM2LCAieSI6IDAuMDIyMDg0NjIzNTc1MjEwNTcs
# ICJ6IjogLTAuOTkwODQwOTcxNDY5ODc5Mn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAw
# fX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43MTY3MTUxMjcwMDUzMDY2LCAieSI6IC0wLjQyMjc2
# MzE5MTI5Nzg5OTMsICJ6IjogLTAuNTU0NjA4NjEwNDY4MTIzOH0sICJub3ciOiAxOTkxMCwgInBv
# c2l0aW9uIjogeyJ4IjogLTAuMjM0NDUxODg5OTkxNzYwMjUsICJ5IjogMC4wMjE3NTMzNTIxMzU0
# MTk4NDYsICJ6IjogLTAuOTkxMDI3MzU1MTk0MDkxOH0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwg
# InoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43MDk4Nzc3MTEwMjU1NjcxLCAieSI6IC0w
# LjQyNTEwNzYyNTc5Mzc2MDQ0LCAieiI6IC0wLjU2MTU2NjY4NTE1OTU1NzR9LCAibm93IjogMTk5
# NDgsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzNDMzMDAyODI5NTUxNjk3LCAieSI6IDAuMDIxNDEx
# Mzk2NTYzMDUzMTMsICJ6IjogLTAuOTkxMjIxMzA4NzA4MTkwOX0sICJ1cCI6IHsieCI6IDAsICJ5
# IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43MDQ2NjQ3NzI1MzY5NTE0LCAi
# eSI6IC0wLjQyNzAxNzAyMzc5MjEzODgsICJ6IjogLTAuNTY2NjYwNDA5NTM3NDV9LCAibm93Ijog
# MTk5ODEsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMzU4ODI5MzE5NDc3MDgsICJ5IjogMC4wMjEy
# NzY0MDUwODExNTI5MTYsICJ6IjogLTAuOTkwMjA1NzA1MTY1ODYzfSwgInVwIjogeyJ4IjogMCwg
# InkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjcwNDcxMjAyOTA2ODg5NjUs
# ICJ5IjogLTAuNDI3ODA5ODgzMzUzMzg5NDMsICJ6IjogLTAuNTY2MDAzMjMzMDIxNDcxNX0sICJu
# b3ciOiAyMDAxMywgInBvc2l0aW9uIjogeyJ4IjogLTAuMjMzMzMyMDUyODI2ODgxNCwgInkiOiAw
# LjAyMTA4MDMwNzY2MjQ4NzAzLCAieiI6IC0wLjk5MDE4Mjg3NjU4NjkxNDF9LCAidXAiOiB7Ingi
# OiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzA4NDc4MzIwODUw
# ODU1NywgInkiOiAtMC40Mjc1ODk4NTk5NTQ3MTUzLCAieiI6IC0wLjU2MTQ0OTM1NzA2NDYwNTZ9
# LCAibm93IjogMjAwNDgsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMzMxMTI1MDgwNTg1NDgsICJ5
# IjogMC4wMjA4NzU3NDgyNDY5MDgxODgsICJ6IjogLTAuOTkwNTE2NjAyOTkzMDExNX0sICJ1cCI6
# IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43MDk1NzUw
# ODUwNjUyODMyLCAieSI6IC0wLjQyNzY0NDQ4Mjc0NDQyNzczLCAieiI6IC0wLjU2MDAyMDg4ODAz
# MjYyMjN9LCAibm93IjogMjAwNzksICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMzQxNDM1MTk0MDE1
# NTAzLCAieSI6IDAuMDIwNzIwMzI1NDEwMzY2MDYsICJ6IjogLTAuOTkwNjQ0NjkzMzc0NjMzOH0s
# ICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43
# MDk2NTg2NDc0NTY5NDU4LCAieSI6IC0wLjQyNzAyMTgzMTY4MjMzNTY1LCAieiI6IC0wLjU2MDM5
# MDAwNjQ3NDI3Nzd9LCAibm93IjogMjAxMTIsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMzQwMDk0
# MDg5NTA4MDU3LCAieSI6IDAuMDIwNjUxODAyNDIwNjE2MTUsICJ6IjogLTAuOTkwNjQ5MjIzMzI3
# NjM2N30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4
# IjogMC43MTA5NjUzNTMwNjQ5OTc1LCAieSI6IC0wLjQyNjM5MDQxOTIxNTY4MTk0LCAieiI6IC0w
# LjU1OTIxMzI2NjI0MzA2NjJ9LCAibm93IjogMjAxNDgsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIz
# MzYwMjQxOTQ5NTU4MjU4LCAieSI6IDAuMDIwNzMyMjUzNzg5OTAxNzMzLCAieiI6IC0wLjk5MDg4
# NDQyMzI1NTkyMDR9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlv
# biI6IHsieCI6IDAuNzEwOTE5Nzg2OTY2MzM3NywgInkiOiAtMC40MjYyNTM0ODM1MDkwOTg3LCAi
# eiI6IC0wLjU1OTM3NTU2NjQwOTYzMDh9LCAibm93IjogMjAxODAsICJwb3NpdGlvbiI6IHsieCI6
# IC0wLjIzMzUyNjU1NzY4Mzk0NDcsICJ5IjogMC4wMjA2Mzc3Nzg1NjUyODc1OSwgInoiOiAtMC45
# OTA4OTI1ODkwOTIyNTQ2fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJl
# Y3Rpb24iOiB7IngiOiAwLjcxMDAyMTE2NTAxMTgzOTEsICJ5IjogLTAuNDI2NTIyODk5OTcxMTI5
# OCwgInoiOiAtMC41NjAzMTA3NzE4MzU5OTQ5fSwgIm5vdyI6IDIwMjE3LCAicG9zaXRpb24iOiB7
# IngiOiAtMC4yMzMxNjUwNTU1MTMzODE5NiwgInkiOiAwLjAyMDUzODYzNTU1MTkyOTQ3NCwgInoi
# OiAtMC45OTA4MTYxNzU5Mzc2NTI2fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwg
# eyJkaXJlY3Rpb24iOiB7IngiOiAwLjcxMDI3NDIyNzAzNjYyMDEsICJ5IjogLTAuNDI3MDUzNjgy
# Mzk5NjA5MywgInoiOiAtMC41NTk1ODUyNzAzMTc2Mzk1fSwgIm5vdyI6IDIwMjUxLCAicG9zaXRp
# b24iOiB7IngiOiAtMC4yMzMxNzA5ODYxNzU1MzcxLCAieSI6IDAuMDIwNjYwMDgwMDE1NjU5MzMy
# LCAieiI6IC0wLjk5MDgzMTE5NjMwODEzNn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAw
# fX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43MTEzMDA5NjM3OTUxNTQxLCAieSI6IC0wLjQyODI3
# NDQ3MDUxMzE0ODI2LCAieiI6IC0wLjU1NzM0MzYyNTQzMjk3MDZ9LCAibm93IjogMjAyOTIsICJw
# b3NpdGlvbiI6IHsieCI6IC0wLjIzMjY2MDYwNjUwMzQ4NjYzLCAieSI6IDAuMDIwNTE2MTg4ODE1
# MjM2MDksICJ6IjogLTAuOTkwNzI4ODU1MTMzMDU2Nn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwg
# InoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43MTMzNjU5NzEyMTUzNTkzLCAieSI6IC0w
# LjQyODcyMTU3NjI1NjE3OTI0LCAieiI6IC0wLjU1NDM1MjU5NjQyNjEyMzR9LCAibm93IjogMjAz
# MTYsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMTk2MTMwOTkwOTgyMDU2LCAieSI6IDAuMDIwMzky
# MDczMzE4MzYyMjM2LCAieiI6IC0wLjk5MDUwMjQxNzA4NzU1NDl9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzE0Mzc4NzA3MTU5ODg5LCAi
# eSI6IC0wLjQyOTc0Nzc0ODM3OTMxMSwgInoiOiAtMC41NTIyNDk4ODUwMzM0Njc0fSwgIm5vdyI6
# IDIwMzQ4LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMzE1OTYzOTUzNzMzNDQ0MiwgInkiOiAwLjAy
# MDQ3Mzg0OTAyODM0ODkyMywgInoiOiAtMC45OTAyMDAxNjE5MzM4OTg5fSwgInVwIjogeyJ4Ijog
# MCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjcxNTEzNDU0NDIxMDI5
# MzQsICJ5IjogLTAuNDMwOTYzNjk4MDk0ODI1NywgInoiOiAtMC41NTAzMjA3MDE1OTI3Nzh9LCAi
# bm93IjogMjAzODIsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIzMDk2MzI0NTAzNDIxNzgzLCAieSI6
# IDAuMDIwMzIzMjkxNDIwOTM2NTg0LCAieiI6IC0wLjk4OTk2MTc0MzM1NDc5NzR9LCAidXAiOiB7
# IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzE5MzMwMzkz
# NTExMzkwNSwgInkiOiAtMC40MzE5MDU5NTU3OTY3MDcwNCwgInoiOiAtMC41NDQwNzgxNDcyNTI4
# MzgxfSwgIm5vdyI6IDIwNDExLCAicG9zaXRpb24iOiB7IngiOiAtMC4yMzAwNjQzNjIyODc1MjEz
# NiwgInkiOiAwLjAyMDE3NDA3ODY0MzMyMTk5LCAieiI6IC0wLjk4OTcyMDgyMTM4MDYxNTJ9LCAi
# dXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzIz
# ODYyOTc4MzQ0NjU5NSwgInkiOiAtMC40MzMxNDQ5NzQ2MDQ5OTQ1LCAieiI6IC0wLjUzNzAzNjE0
# MzYyMjA0NTJ9LCAibm93IjogMjA0NDcsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIyOTIyNjk0Njgz
# MDc0OTUsICJ5IjogMC4wMjAxMzkyNDkwNDE2NzY1MiwgInoiOiAtMC45ODk1NTE0MjQ5ODAxNjM2
# fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAw
# LjcyNTUzNTQ2OTkxMjY4NjcsICJ5IjogLTAuNDM1MjA3NjI5NzA3NjY0OTcsICJ6IjogLTAuNTMz
# MDk3MTc3NzY2NjkyOX0sICJub3ciOiAyMDQ4MiwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjI4MTAx
# ODk0MjU5NDUyODIsICJ5IjogMC4wMjAwMjI2Mjg4Mjg4ODMxNywgInoiOiAtMC45ODkxODE5MzU3
# ODcyMDA5fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7
# IngiOiAwLjcyOTExMTE2NjU3ODMxMjgsICJ5IjogLTAuNDM1NTU3MzE5MzUwMjA2NzUsICJ6Ijog
# LTAuNTI3OTA3ODc4NjQxMDMxNH0sICJub3ciOiAyMDUxOCwgInBvc2l0aW9uIjogeyJ4IjogLTAu
# MjI3MDE0ODU0NTUwMzYxNjMsICJ5IjogMC4wMjAwMjI5MjMxMjY4MTY3NSwgInoiOiAtMC45ODg3
# ODYzOTkzNjQ0NzE0fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rp
# b24iOiB7IngiOiAwLjczNDIxNDQ1MTkyOTgzNjEsICJ5IjogLTAuNDM1MTY0NTUzMzcwMzg0Miwg
# InoiOiAtMC41MjExMTUxMDI1MTMxODIzfSwgIm5vdyI6IDIwNTQ3LCAicG9zaXRpb24iOiB7Ingi
# OiAtMC4yMjY0MDA0OTQ1NzU1MDA1LCAieSI6IDAuMDIwMDMxMTE4NzY1NDczMzY2LCAieiI6IC0w
# Ljk4ODU4NTY1MDkyMDg2Nzl9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRp
# cmVjdGlvbiI6IHsieCI6IDAuNzM1NjQ5NjAxMDQ4Mjc1LCAieSI6IC0wLjQzNTc5ODYxOTI2ODQ1
# NDIsICJ6IjogLTAuNTE4NTU0OTQyMDQ2ODYwNn0sICJub3ciOiAyMDU3NywgInBvc2l0aW9uIjog
# eyJ4IjogLTAuMjI1NTIyNDI4NzUwOTkxODIsICJ5IjogMC4wMjAwNTgzNjE4MTM0MjYwMTgsICJ6
# IjogLTAuOTg3OTkzOTU1NjEyMTgyNn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0s
# IHsiZGlyZWN0aW9uIjogeyJ4IjogMC43Mzg0ODk4MzE4NTAwNTI1LCAieSI6IC0wLjQzNTU1NTc3
# NDY4MjE1MTksICJ6IjogLTAuNTE0NzA3NjIxMjcxNjQxN30sICJub3ciOiAyMDYxMywgInBvc2l0
# aW9uIjogeyJ4IjogLTAuMjI0NjE5Mjk5MTczMzU1MSwgInkiOiAwLjAyMDE0MzIxMDg4NzkwODkz
# NiwgInoiOiAtMC45ODczMDc1NDg1MjI5NDkyfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6
# IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjc0NTIxOTI3NTcyOTc3NzEsICJ5IjogLTAuNDMz
# OTE0OTk2Nzk3OTk0NywgInoiOiAtMC41MDYzMjU5ODg1MDQwMjk3fSwgIm5vdyI6IDIwNjQ1LCAi
# cG9zaXRpb24iOiB7IngiOiAtMC4yMjQzNjM2MjUwNDk1OTEwNiwgInkiOiAwLjAyMDI1NTcyMjEw
# NTUwMzA4MiwgInoiOiAtMC45ODcwMTk0MTk2NzAxMDV9LCAidXAiOiB7IngiOiAwLCAieSI6IDEs
# ICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzQ4MTA1OTcyNDk5MDUzNiwgInkiOiAt
# MC40MzQ4NDgyODMxNzM1MzI4LCAieiI6IC0wLjUwMTI0Mjg3OTc4MjEyMzZ9LCAibm93IjogMjA2
# ODIsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIyMzYxMzMyMTc4MTE1ODQ1LCAieSI6IDAuMDIwMDQx
# MjQwMzc5MjE0Mjg3LCAieiI6IC0wLjk4NjU2NTA1MzQ2Mjk4MjJ9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzQ3NDExMzMwNDkxNDQ0NSwg
# InkiOiAtMC40MzgwNzY1MDA3OTY4ODI3LCAieiI6IC0wLjQ5OTQ2NDk5NjI3MzU4MDA0fSwgIm5v
# dyI6IDIwNzEwLCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjI0MzAzMDM2OTI4MTc3LCAieSI6IDAu
# MDE5NjM1MzY4MTM4NTUxNzEyLCAieiI6IC0wLjk4NjAxMjI3OTk4NzMzNTJ9LCAidXAiOiB7Ingi
# OiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzUwMDc2Mzg5NTQ5
# NDI1OSwgInkiOiAtMC40MzkyNTg1NjQzMTIzNjk2NSwgInoiOiAtMC40OTQ0MDYwMzEwMjk4OTUx
# fSwgIm5vdyI6IDIwNzQ2LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjEwNjI1ODU3MTE0NzkyLCAi
# eSI6IDAuMDE5MzE0MzQxMjQ3MDgxNzU3LCAieiI6IC0wLjk4NTE5MTY0MzIzODA2NzZ9LCAidXAi
# OiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNzU5MTE5
# NDI4ODgwOTE3OSwgInkiOiAtMC40MzY1NDM3MDk5NTIxNzc1NiwgInoiOiAtMC40ODI4NzM5ODE0
# ODY1NzU3fSwgIm5vdyI6IDIwNzc5LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMjAwOTQ4NzQ1MDEy
# MjgzMywgInkiOiAwLjAxODY1NDIxMDQ5Mjk2ODU2LCAieiI6IC0wLjk4NDU2NDg0MDc5MzYwOTZ9
# LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAu
# NzY1NjEwMzkxNjA2NDUxLCAieSI6IC0wLjQzNTUzNzQyNjY0MTcyMDQ2LCAieiI6IC0wLjQ3MzQ0
# MjU4MTc5NjkxMTA3fSwgIm5vdyI6IDIwODE3LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMTg3NzI1
# MTU2NTQ1NjM5LCAieSI6IDAuMDE4NDc3OTQyNzk0NTYxMzg2LCAieiI6IC0wLjk4MzM4NjY5NTM4
# NDk3OTJ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsi
# eCI6IDAuNzY3MDY1NTg1NzU2NDAxNywgInkiOiAtMC40MzY2OTY2NjY1ODIwMDk3LCAieiI6IC0w
# LjQ3MDAwNjgxNzU1MDkyNTh9LCAibm93IjogMjA4NDUsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIx
# NzIwNTU2OTE0ODA2MzY2LCAieSI6IDAuMDE4MzA5Njg4MTk1NTg2MjA1LCAieiI6IC0wLjk4MjEy
# OTYzMzQyNjY2NjN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlv
# biI6IHsieCI6IDAuNzcwNzg3OTM4MDg3NzY0MiwgInkiOiAtMC40MzYwNDg3MTkwNDg5MDUsICJ6
# IjogLTAuNDY0NDg2MjQyMTE1MTE1OX0sICJub3ciOiAyMDg4MCwgInBvc2l0aW9uIjogeyJ4Ijog
# LTAuMjE1NTEzMjQ0MjcxMjc4MzgsICJ5IjogMC4wMTg0MDU0MDM5NDE4Njk3MzYsICJ6IjogLTAu
# OTc5NzMyMjE1NDA0NTEwNX0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGly
# ZWN0aW9uIjogeyJ4IjogMC43NzY5MDQxMzcyODE3ODM5LCAieSI6IC0wLjQzMzk5NTEyMTcxNzY3
# MTcsICJ6IjogLTAuNDU2MTQ0OTI4NTAzNzcxMDN9LCAibm93IjogMjA5MTMsICJwb3NpdGlvbiI6
# IHsieCI6IC0wLjIxNDA4OTU0MjYyNzMzNDYsICJ5IjogMC4wMTg2MTIxMDUzOTkzNzAxOTMsICJ6
# IjogLTAuOTc4MTE4OTU2MDg5MDE5OH0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0s
# IHsiZGlyZWN0aW9uIjogeyJ4IjogMC43ODQxOTUzOTgwNDYyMjE4LCAieSI6IC0wLjQzMTA4MjU4
# ODg4MDEwMDg3LCAieiI6IC0wLjQ0NjMyNDI5ODI5MzkxN30sICJub3ciOiAyMDk0NywgInBvc2l0
# aW9uIjogeyJ4IjogLTAuMjEzMDU2MDQyNzkwNDEyOSwgInkiOiAwLjAxODE3OTcyMzk5Mjk0Mzc2
# NCwgInoiOiAtMC45NzY5NDEwNDkwOTg5Njg1fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6
# IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjc4OTk5NTc3NDkwNTM1MiwgInkiOiAtMC40Mjg3
# MTU1MzEyNDQwMDksICJ6IjogLTAuNDM4MzAzMTcwMDc5NjM3NTR9LCAibm93IjogMjA5ODEsICJw
# b3NpdGlvbiI6IHsieCI6IC0wLjIxMTk5MTAxMjA5NjQwNTAzLCAieSI6IDAuMDE4NDU4NzUxOTYx
# NTg4ODYsICJ6IjogLTAuOTc1NTAzMjY1ODU3Njk2NX0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwg
# InoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC43OTgxMzI5NTI4NDA3NDQ1LCAieSI6IC0w
# LjQyNTYzNzYxMDk0ODQ4MzUsICJ6IjogLTAuNDI2Mzk5MzU5NDQ1NzkxNX0sICJub3ciOiAyMTAx
# NCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjEwOTMxODk3MTYzMzkxMSwgInkiOiAwLjAxODcwOTU5
# OTk3MTc3MTI0LCAieiI6IC0wLjk3NDIzMDE3MDI0OTkzOX0sICJ1cCI6IHsieCI6IDAsICJ5Ijog
# MSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44MDcyMTg4MDkwODcwODk0LCAieSI6
# IC0wLjQyMjE1MjU3OTI1MjAwMjQ1LCAieiI6IC0wLjQxMjUzNDgzOTg0NjE2NzM0fSwgIm5vdyI6
# IDIxMDQ2LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMDk4MjA1NTM2NjAzOTI3NiwgInkiOiAwLjAx
# ODk2ODk2MDI3MDI4NTYwNiwgInoiOiAtMC45NzI5NTgwODc5MjExNDI2fSwgInVwIjogeyJ4Ijog
# MCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjgxMzY2OTc0Mjc3MTYx
# NjcsICJ5IjogLTAuNDE3MjI3MjYyMTU1MTgyOSwgInoiOiAtMC40MDQ3OTk5MDI5MzA0MDAxfSwg
# Im5vdyI6IDIxMDgyLCAicG9zaXRpb24iOiB7IngiOiAtMC4yMTAyMTcxMTgyNjMyNDQ2MywgInki
# OiAwLjAxODI5OTk1MjE0OTM5MTE3NCwgInoiOiAtMC45NzE5NTUxODAxNjgxNTE5fSwgInVwIjog
# eyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjgxNzYyOTAx
# MjkzODI2NTQsICJ5IjogLTAuNDE0NjU2ODE4ODI0ODg3NzUsICJ6IjogLTAuMzk5NDI3NzQwNDAz
# MjIwMDR9LCAibm93IjogMjExMTQsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIwOTQyMDMzODI3MzA0
# ODQsICJ5IjogMC4wMTg1ODAxNDYxMzM4OTk2OSwgInoiOiAtMC45NzA0OTQzMjk5MjkzNTE4fSwg
# InVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjgy
# NjYyMjU3ODM0MDg4NTksICJ5IjogLTAuNDA5NzA3NTU5MjU1MTYxMywgInoiOiAtMC4zODU3OTEx
# NzI2MTMxNjkyNX0sICJub3ciOiAyMTE0OSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjA4NDkwOTM3
# OTQ4MjI2OTMsICJ5IjogMC4wMTg5MzQzMzU1NTk2MDY1NTIsICJ6IjogLTAuOTY4ODQyMTQ4Nzgw
# ODIyOH0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4
# IjogMC44MzY5MTM3MzQwODU4OTg2LCAieSI6IC0wLjQwMzgxNTE5NjgyMTQ5NDQsICJ6IjogLTAu
# MzY5NDcwODIyMjc3NTA0ODN9LCAibm93IjogMjExODIsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIw
# ODQ1MDM5MTg4ODYxODQ3LCAieSI6IDAuMDE5Njk3NTYxODYwMDg0NTM0LCAieiI6IC0wLjk2ODA3
# MzM2ODA3MjUwOTh9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlv
# biI6IHsieCI6IDAuODQwNzc0MTM0OTQ0MDU2MywgInkiOiAtMC40MDE1MjMxMTU2OTIwMTk5LCAi
# eiI6IC0wLjM2MzE1MDE2Mzk0NjA1NDg3fSwgIm5vdyI6IDIxMjE4LCAicG9zaXRpb24iOiB7Ingi
# OiAtMC4yMDc1NTg3MjEzMDM5Mzk4MiwgInkiOiAwLjAxOTg1NzgwNTIyMjI3Mjg3MywgInoiOiAt
# MC45NjY2NTQyNDEwODUwNTI1fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJk
# aXJlY3Rpb24iOiB7IngiOiAwLjg0MTYyMDE4NTY2MTkxMywgInkiOiAtMC40MDE4MTYxNzM4MTA0
# MTIxLCAieiI6IC0wLjM2MDg1OTAxMDYyNzA5NzYzfSwgIm5vdyI6IDIxMjUxLCAicG9zaXRpb24i
# OiB7IngiOiAtMC4yMDc0Mjk5NDU0Njg5MDI2LCAieSI6IDAuMDIwMjA1MDI2NDkyNDc2NDYzLCAi
# eiI6IC0wLjk2NjEyMDYwMDcwMDM3ODR9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19
# LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODQ1MzMyMTM0MzYxNTE5NywgInkiOiAtMC40MDIyMDQ3
# MTkxMTk3NjAyLCAieiI6IC0wLjM1MTYzMTgzMzc4ODY4Mzh9LCAibm93IjogMjEyODQsICJwb3Np
# dGlvbiI6IHsieCI6IC0wLjIwNjM3MzI1OTQyNTE2MzI3LCAieSI6IDAuMDE5OTU2MjQ5NzQzNzAw
# MDI3LCAieiI6IC0wLjk2NDg0NTg5NTc2NzIxMTl9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6
# IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuODQ5OTU3MTc4ODA0MDA0MSwgInkiOiAtMC40
# MDM3NDg2NTEyODg1NTc2LCAieiI6IC0wLjMzODQ2Njg2ODA3MTYxNjI0fSwgIm5vdyI6IDIxMzE4
# LCAicG9zaXRpb24iOiB7IngiOiAtMC4yMDQ5OTM0MjY3OTk3NzQxNywgInkiOiAwLjAxOTQ2MzEy
# NTYxNjMxMjAyNywgInoiOiAtMC45NjM1MDY1MTk3OTQ0NjQxfSwgInVwIjogeyJ4IjogMCwgInki
# OiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjg1MzQ4Mzc5MjE0ODY4NDEsICJ5
# IjogLTAuNDA2ODIzODI2OTQyNTY4OCwgInoiOiAtMC4zMjU2NjgyMjEzMTAxMzEwN30sICJub3ci
# OiAyMTM0OSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjAzMzU4NTMwOTk4MjI5OTgsICJ5IjogMC4w
# MTg4MzgzMTI0NzY4NzMzOTgsICJ6IjogLTAuOTYxOTQyOTcwNzUyNzE2MX0sICJ1cCI6IHsieCI6
# IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44NTUwNjYyMjY2MDE4
# MDM4LCAieSI6IC0wLjQxMDA4MTY0MjQ1Njc4Njg1LCAieiI6IC0wLjMxNzMyNDQzMTIxMzM4Mjd9
# LCAibm93IjogMjEzODQsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIwMzYwNjgxNDE0NjA0MTg3LCAi
# eSI6IDAuMDE4Nzg4NjA1OTI4NDIxMDIsICJ6IjogLTAuOTYwNTM4ODA0NTMxMDk3NH0sICJ1cCI6
# IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44NTg5MTkz
# NzEwMzM3MzksICJ5IjogLTAuNDExMTU5MTgyNzk2OTA4MiwgInoiOiAtMC4zMDUyOTU5ODgyODgw
# NjI2NX0sICJub3ciOiAyMTQyMCwgInBvc2l0aW9uIjogeyJ4IjogLTAuMjAyMzk1MTQxMTI0NzI1
# MzQsICJ5IjogMC4wMTg0ODI1NzUxOTMwNDc1MjMsICJ6IjogLTAuOTU4NDY4Mzc3NTkwMTc5NH0s
# ICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC44
# NjQxODI2NTYzMDk1MDk1LCAieSI6IC0wLjQwOTU0OTk4NzEwODc4MjQzLCAieiI6IC0wLjI5MjMz
# MDUzOTk1OTU0MDN9LCAibm93IjogMjE0NDYsICJwb3NpdGlvbiI6IHsieCI6IC0wLjIwMzc3Nzk2
# ODg4MzUxNDQsICJ5IjogMC4wMTgzMjUzNDc0NTMzNTU3OSwgInoiOiAtMC45NTY1MDUyOTg2MTQ1
# MDJ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6
# IDAuMjk4MjQ1MzMyOTM0NTE4MDUsICJ5IjogLTAuNDA4MjgyMTgwNjc1Mzc0LCAieiI6IC0wLjg2
# Mjc2MDMyNzI3ODUyMDZ9LCAibm93IjogMjE0ODEsICJwb3NpdGlvbiI6IHsieCI6IC0wLjAyNDcx
# OTU5OTYzNDQwODk1LCAieSI6IDAuMDQ2NjUxODIxNTgzNTA5NDQ1LCAieiI6IDAuMTIxMjczMzgz
# NDk4MTkxODN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6
# IHsieCI6IDAuMzA3NjQxMDU1ODU4NDA0OCwgInkiOiAtMC40MDg4MzQyNDQyMDc5NTk1LCAieiI6
# IC0wLjg1OTE5MjM3NzQ3NjIxNn0sICJub3ciOiAyMTUyMCwgInBvc2l0aW9uIjogeyJ4IjogLTAu
# MDIyMzEwODg2NTMyMDY4MjUzLCAieSI6IDAuMDQ2NjYwMDA5NzcxNTg1NDY0LCAieiI6IDAuMTIy
# MDA4OTQyMDY3NjIzMTR9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVj
# dGlvbiI6IHsieCI6IDAuMzE4NTU2OTcyMTY2MTg0NSwgInkiOiAtMC40MDgwMDU1MjM1NzY0OTk1
# LCAieiI6IC0wLjg1NTYwMDkyODEyOTEwMTJ9LCAibm93IjogMjE1NTQsICJwb3NpdGlvbiI6IHsi
# eCI6IC0wLjAxOTkzNDQ0NTYxOTU4MzEzLCAieSI6IDAuMDQ2ODA3NjMxODUwMjQyNjE1LCAieiI6
# IDAuMTIyODA3MzE2NDgyMDY3MTF9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7
# ImRpcmVjdGlvbiI6IHsieCI6IDAuMzI2NjAwOTI0MzY2MTAzNSwgInkiOiAtMC40MDc1MTc2Nzc0
# NjE1Mzg0LCAieiI6IC0wLjg1Mjc5NjA5NDQ3OTU0MjN9LCAibm93IjogMjE1ODgsICJwb3NpdGlv
# biI6IHsieCI6IC0wLjAxNzYyNzgzMTU0ODQ1MjM3NywgInkiOiAwLjA0ODAzMTk4OTQ4NTAyNTQw
# NiwgInoiOiAwLjEyNDE3MTQwNjAzMDY1NDkxfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6
# IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjMzODI4NTE1NDYzMTQxOTM0LCAieSI6IC0wLjQw
# NTIyNDU4NzE3OTg4MDYsICJ6IjogLTAuODQ5MzI2OTAyOTY1NDU1NH0sICJub3ciOiAyMTYxOSwg
# InBvc2l0aW9uIjogeyJ4IjogLTAuMDE1OTAxNDc5ODcwMDgwOTQ4LCAieSI6IDAuMDQ4MzM3NTEx
# NzE4MjczMTYsICJ6IjogMC4xMjQ5NjgzMzUwMzI0NjMwN30sICJ1cCI6IHsieCI6IDAsICJ5Ijog
# MSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC4zNTIwNDk5MjUzMTExNTA2NSwgInki
# OiAtMC40MDM0MjY5Njk0NjMxOTYzLCAieiI6IC0wLjg0NDU3NTM1NTA3Mzg3MDR9LCAibm93Ijog
# MjE2NTQsICJwb3NpdGlvbiI6IHsieCI6IC0wLjAxNDg0MzcxMzQ5MjE1NTA3NSwgInkiOiAwLjA0
# ODg5NDA4MTI2NDczNDI3LCAieiI6IDAuMTI1NjEyODI1MTU1MjU4MTh9LCAidXAiOiB7IngiOiAw
# LCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuMzYxNjIwMDMyMjQxMTQw
# NiwgInkiOiAtMC40MDIzNzk1NDYxMjc0NjE5NiwgInoiOiAtMC44NDEwMjQxNjkxNzcxODQ4fSwg
# Im5vdyI6IDIxNjg2LCAicG9zaXRpb24iOiB7IngiOiAtMC4wMTMwOTU3MjE2MDI0Mzk4OCwgInki
# OiAwLjA0ODk4NjczNjY4NTAzNzYxLCAieiI6IDAuMTI2MzQ3Njc1OTE5NTMyNzh9LCAidXAiOiB7
# IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuMzYzODk0ODQ5
# ODIyNDk2MSwgInkiOiAtMC40MDM5MDExMzA5NzYxOTE4LCAieiI6IC0wLjgzOTMxMTg2OTcyOTQ5
# MjN9LCAibm93IjogMjE3MjEsICJwb3NpdGlvbiI6IHsieCI6IC0wLjAxMTM2NjQ3NTM3MzUwNjU0
# NiwgInkiOiAwLjA0ODc0OTE4OTgyMzg2NTg5LCAieiI6IDAuMTI2NzUwNzk3MDMzMzA5OTR9LCAi
# dXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuMzc0
# NTM4NTUyMjI5NjUxMjcsICJ5IjogLTAuNDA0OTc5NzY4NzczNjU5MiwgInoiOiAtMC44MzQwOTM2
# NzU2NjEwNDM1fSwgIm5vdyI6IDIxNzUzLCAicG9zaXRpb24iOiB7IngiOiAtMC4wMDkxNTI4NzA2
# MjUyNTc0OTIsICJ5IjogMC4wNDc5MDMwNzIwODg5NTY4MywgInoiOiAwLjEyNjYwMzIxNTkzMjg0
# NjA3fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7Ingi
# OiAwLjM5MDkyMzA5NjQ2MjUyMTY2LCAieSI6IC0wLjQwMzQwNDQzMzI5NDgzMDcsICJ6IjogLTAu
# ODI3MzExMzA1MjgzNzA2N30sICJub3ciOiAyMTc4OSwgInBvc2l0aW9uIjogeyJ4IjogLTAuMDA2
# NTY1NTQ0NzU0MjY2NzM5LCAieSI6IDAuMDQ3NDIzNDUyMTM4OTAwNzYsICJ6IjogMC4xMjY4OTA0
# ODA1MTgzNDEwNn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9u
# IjogeyJ4IjogMC40MDEwNTA1MDE4NzkyNTQ2LCAieSI6IC0wLjQwMzE0NDA0ODU2NzYxNDQsICJ6
# IjogLTAuODIyNTc3MjczNjAyMjUwMn0sICJub3ciOiAyMTgyMywgInBvc2l0aW9uIjogeyJ4Ijog
# LTAuMDA0MDY0NDI1ODI2MDcyNjkzLCAieSI6IDAuMDQ2ODg0MzEzMjI1NzQ2MTU1LCAieiI6IDAu
# MTI2OTQ0MDc5OTk1MTU1MzN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRp
# cmVjdGlvbiI6IHsieCI6IDAuNDA3MTA0NjkzNjY0OTQ3MDYsICJ5IjogLTAuNDA1MjM5MTgwMzMw
# NDUxOSwgInoiOiAtMC44MTg1NjM5NzEzMDY1MDI3fSwgIm5vdyI6IDIxODU1LCAicG9zaXRpb24i
# OiB7IngiOiAtMC4wMDE5NTczNDIwMjg2MTc4NTksICJ5IjogMC4wNDY4NzcyNDI2MjQ3NTk2NzQs
# ICJ6IjogMC4xMjcyOTkzMDg3NzY4NTU0N30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAw
# fX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MTI3NjgyNzA4NTI4NzM2LCAieSI6IC0wLjQwNTgy
# NzMwOTcwNDIxNTY2LCAieiI6IC0wLjgxNTQzMDI4NDc0MjU4MTZ9LCAibm93IjogMjE4ODksICJw
# b3NpdGlvbiI6IHsieCI6IC0wLjAwMDE2OTcyMDUwMDcwNzYyNjM0LCAieSI6IDAuMDQ2NTExNTkw
# NDgwODA0NDQsICJ6IjogMC4xMjcyNTg5NzEzMzM1MDM3Mn0sICJ1cCI6IHsieCI6IDAsICJ5Ijog
# MSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MTQ5MTc2NzExNzk5MzM2LCAieSI6
# IC0wLjQwNjQ3NzM1NjA4NzkxNjYsICJ6IjogLTAuODE0MDE0NDI1NjI3OTQ3Nn0sICJub3ciOiAy
# MTkyNCwgInBvc2l0aW9uIjogeyJ4IjogMC4wMDEyNjE1Mzk3NTcyNTE3Mzk1LCAieSI6IDAuMDQ2
# MjQ0MzkwMzA4ODU2OTY0LCAieiI6IDAuMTI3MjIxMjcxMzk1NjgzM30sICJ1cCI6IHsieCI6IDAs
# ICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MTczNTU5OTExNjEzMTMx
# LCAieSI6IC0wLjQwNzEwNjAxNDUyNzIwNjQ2LCAieiI6IC0wLjgxMjQ1MjI1Njc5ODg0MjN9LCAi
# bm93IjogMjE5NTUsICJwb3NpdGlvbiI6IHsieCI6IDAuMDAxODQ0NTI1MzM3MjE5MjM4MywgInki
# OiAwLjA0NjY0Nzg2NTMyNTIxMjQ4LCAieiI6IDAuMTI3MzE2MjY2Mjk4Mjk0MDd9LCAidXAiOiB7
# IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDIwOTM3NjY4
# ODgzMzAzLCAieSI6IC0wLjQwNjI5MDM4NjczMDgyNDEsICJ6IjogLTAuODExMDExNDY3NTkxNjc4
# NX0sICJub3ciOiAyMTk5MCwgInBvc2l0aW9uIjogeyJ4IjogMC4wMDIyNjA3NDA4NDYzOTU0OTI2
# LCAieSI6IDAuMDQ2NDc5NjEyNTg4ODgyNDQ2LCAieiI6IDAuMTI3MjI5MjU4NDE4MDgzMn0sICJ1
# cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MjA1
# MTI2NzA2NzU3NjQ1LCAieSI6IC0wLjQwNjgxNTc3MDg1Mzk5Nzk1LCAieiI6IC0wLjgxMDk2ODU3
# MDUyODg0ODN9LCAibm93IjogMjIwMjQsICJwb3NpdGlvbiI6IHsieCI6IDAuMDAyNDM5MDcwNDky
# OTgyODY0NCwgInkiOiAwLjA0NjEyNDcxOTA4MzMwOTE3NCwgInoiOiAwLjEyNjgzOTA1NjYxMTA2
# MTF9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6
# IDAuNDE5MTk1Nzk1Mzg5ODU0NSwgInkiOiAtMC40MDk4NzI1MTg4OTU3NDQ0LCAieiI6IC0wLjgx
# MDExMDczNTI1ODc4MjN9LCAibm93IjogMjIwNTgsICJwb3NpdGlvbiI6IHsieCI6IDAuMDAwODUw
# NjQ3Njg3OTExOTg3MywgInkiOiAwLjA0NjY1NTg0MTE3MTc0MTQ4NiwgInoiOiAwLjEyNjczMDM2
# NzU0MTMxMzE3fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24i
# OiB7IngiOiAwLjQxOTk1NDcyOTI2NTA0OTEsICJ5IjogLTAuNDExNjg3NzEyMTkyNjQxNTUsICJ6
# IjogLTAuODA4Nzk2MTc1MTg3MjM5OH0sICJub3ciOiAyMjA5MSwgInBvc2l0aW9uIjogeyJ4Ijog
# MC4wMDEwMTQzOTI4MjI5ODA4ODA3LCAieSI6IDAuMDQ2Mjc3OTg4NzAyMDU4NzksICJ6IjogMC4x
# MjYwMzE4MTYwMDU3MDY4fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJl
# Y3Rpb24iOiB7IngiOiAwLjQxOTUyOTc3MTA1NDI2NjcsICJ5IjogLTAuNDE1MDc2NTU1NjYzNzUw
# ODUsICJ6IjogLTAuODA3MjgzMjM2NjI2MDc1fSwgIm5vdyI6IDIyMTI1LCAicG9zaXRpb24iOiB7
# IngiOiAwLjAwMTUyOTU5MzAyMDY3NzU2NjUsICJ5IjogMC4wNDU4MzIxNDIyMzM4NDg1NywgInoi
# OiAwLjEyNTAxNjAwMzg0NzEyMjJ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7
# ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE4NDgxODMwNTEyNzgxMjYsICJ5IjogLTAuNDE5NzEzNjYy
# ODQ0MTM1NSwgInoiOiAtMC44MDU0Mjc0NjMzNzEyNDA2fSwgIm5vdyI6IDIyMTYwLCAicG9zaXRp
# b24iOiB7IngiOiAwLjAwMTY3NDgyNzE4ODI1MzQwMjcsICJ5IjogMC4wNDU5MDAzNzgzNzYyNDU1
# LCAieiI6IDAuMTI0NDY3MzM1NjQxMzg0MTJ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6Ijog
# MH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE3MDQyMDUyNjE3NzkxLCAieSI6IC0wLjQyNDIz
# NzE5NDc0NzMzMzU3LCAieiI6IC0wLjgwMzgwMjY2NzkxMTI1Nn0sICJub3ciOiAyMjE5MCwgInBv
# c2l0aW9uIjogeyJ4IjogMC4wMDI5NzA0ODMxNTQwNTg0NTY0LCAieSI6IDAuMDQ1NTQ4Njk2MDcw
# OTA5NSwgInoiOiAwLjEyMzM2Mjk1ODQzMTI0Mzl9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6
# IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE3OTAzNzc1NjI4MjE2NiwgInkiOiAtMC40
# MjUzMzUxOTc4MjkyNDUxLCAieiI6IC0wLjgwMjc3NDE5MjI4Nzc0Mjl9LCAibm93IjogMjIyMjUs
# ICJwb3NpdGlvbiI6IHsieCI6IDAuMDA0MzAyOTQ4NzEzMzAyNjEyLCAieSI6IDAuMDQ1Mzg3ODc1
# Mjg4NzI0OSwgInoiOiAwLjEyMjI5NzczNDAyMjE0MDV9LCAidXAiOiB7IngiOiAwLCAieSI6IDEs
# ICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE2NTk1NjQyMTEzNzEyMSwgInkiOiAt
# MC40MjY3OTY5NjQ5OTA4MDUyNywgInoiOiAtMC44MDI2NzgyODAyODgyNDkyfSwgIm5vdyI6IDIy
# MjU2LCAicG9zaXRpb24iOiB7IngiOiAwLjAwNTY3MDU2NjExMTgwMzA1NSwgInkiOiAwLjA0NDA2
# ODkwMjczMDk0MTc3LCAieiI6IDAuMTIwNDMwNzYwMDg1NTgyNzN9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE2NzQyNzE3ODIwNTc5Mywg
# InkiOiAtMC40MzAwMDQ0NDgzMzQ3OTYzLCAieiI6IC0wLjgwMDg4ODA1ODA2NzkyMDV9LCAibm93
# IjogMjIyOTEsICJwb3NpdGlvbiI6IHsieCI6IDAuMDA3MzEzNjE2NTczODEwNTc3LCAieSI6IDAu
# MDQzNDg0MTg0ODkwOTg1NDksICJ6IjogMC4xMTg4MjI3NzU3ODExNTQ2M30sICJ1cCI6IHsieCI6
# IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MTg4NjY5Mjc3MTMx
# NzMzNSwgInkiOiAtMC40MzI3NjAzODc5MDY4MjA4LCAieiI6IC0wLjc5ODI5MTI2NDg0NDM5NTd9
# LCAibm93IjogMjIzMjQsICJwb3NpdGlvbiI6IHsieCI6IDAuMDA5MTUwNjk1MDU1NzIzMTksICJ5
# IjogMC4wNDI5Mzc4MjYzNjUyMzI0NywgInoiOiAwLjExNzA5MTYxMTAyNzcxNzU5fSwgInVwIjog
# eyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQyMDc1Njc2
# Mjc3MjM5NzcsICJ5IjogLTAuNDM0MDc5Mjg2MzkxMjg3MDcsICJ6IjogLTAuNzk2NTc5NTEyNDgy
# NzkyNH0sICJub3ciOiAyMjM1OCwgInBvc2l0aW9uIjogeyJ4IjogMC4wMTEwMTEwMTM3NjExNjI3
# NTgsICJ5IjogMC4wNDIzMzIyNDY4OTk2MDQ4LCAieiI6IDAuMTE1MjQ0NzE2NDA1ODY4NTN9LCAi
# dXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDIz
# NTM0MzcxMjcwMzUxOSwgInkiOiAtMC40MzgzNjcyNTY0OTI2MjY5LCAieiI6IC0wLjc5Mjc1MDE0
# MDIwMDQwMDl9LCAibm93IjogMjIzODcsICJwb3NpdGlvbiI6IHsieCI6IDAuMDEyOTU5NjYyODI0
# ODY5MTU2LCAieSI6IDAuMDQxMjY3MTQ5MTUwMzcxNTUsICJ6IjogMC4xMTI0MDIzMzQ4MDkzMDMy
# OH0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4Ijog
# MC40MjkzMzIxOTc3MzYzMzYxLCAieSI6IC0wLjQ0MDU0NjE0ODY0NzQ4OTc1LCAieiI6IC0wLjc4
# ODQxMTY2NTg4MTk0OTh9LCAibm93IjogMjI0MjEsICJwb3NpdGlvbiI6IHsieCI6IDAuMDE0NzM3
# MzI2NjUxODExNiwgInkiOiAwLjA0MDE3MDczNjYxMDg4OTQzNSwgInoiOiAwLjEwOTYyNTA0ODkz
# NTQxMzM2fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7
# IngiOiAwLjQyNzIxNTY5NjM0NTUxMzUsICJ5IjogLTAuNDQ3OTE2NzQ4MDg3NTY4NCwgInoiOiAt
# MC43ODU0MDI2NTgyNDUyMzE0fSwgIm5vdyI6IDIyNDU1LCAicG9zaXRpb24iOiB7IngiOiAwLjAx
# Njg1NzM4MTkxMDA4NTY3OCwgInkiOiAwLjAzODU1NjkyOTY3NzcyNDg0LCAieiI6IDAuMTA1Njcw
# NTE5MTczMTQ1M30sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9u
# IjogeyJ4IjogMC40MjM3MDE3ODg3NzExODcxNCwgInkiOiAtMC40NTgzNjE1MTM5NTYwNDQ0Niwg
# InoiOiAtMC43ODEyNjkxNzA0NjMwNDgxfSwgIm5vdyI6IDIyNDg5LCAicG9zaXRpb24iOiB7Ingi
# OiAwLjAxODk0NzcyNDI1MjkzOTIyNCwgInkiOiAwLjAzNjc1NDgxNjc3MDU1MzU5LCAieiI6IDAu
# MTAxMzYzOTQ5NDc3NjcyNTh9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRp
# cmVjdGlvbiI6IHsieCI6IDAuNDI0NzA2NjU4NzE5MzQ5NiwgInkiOiAtMC40NjM4OTc1NDUxNzgx
# NTQzNSwgInoiOiAtMC43Nzc0NDY2NjgwMjExMTEyfSwgIm5vdyI6IDIyNTI0LCAicG9zaXRpb24i
# OiB7IngiOiAwLjAyMTA2NTM1NjIwOTg3NDE1MywgInkiOiAwLjAzNTI2NjE4MzMxNjcwNzYxLCAi
# eiI6IDAuMDk3MDMwMzkzNzc5Mjc3OH0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0s
# IHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MjY4MDI5NTk1MjkxNjk4NiwgInkiOiAtMC40NjkwMjYy
# MTA4NzQ4ODczMywgInoiOiAtMC43NzMyMDk5NjMyMzczMzkzfSwgIm5vdyI6IDIyNTY4LCAicG9z
# aXRpb24iOiB7IngiOiAwLjAyMzM0NzkzODQzMzI4OTUyOCwgInkiOiAwLjAzMzQxOTMxMTA0NjYw
# MDM0LCAieiI6IDAuMDkxODAyMDk3ODU2OTk4NDR9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6
# IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDIxNzIxNTQwNDEzOTkyNzMsICJ5IjogLTAu
# NDc5MzM4MjQ0MzkxNTEwNTcsICJ6IjogLTAuNzY5NjY2MDI0ODUzOTcxMX0sICJub3ciOiAyMjU4
# OSwgInBvc2l0aW9uIjogeyJ4IjogMC4wMjY0NTU1ODg2Mzg3ODI1LCAieSI6IDAuMDMxOTI5MDcx
# OTkyNjM1NzMsICJ6IjogMC4wODY5NzY5ODI2NTMxNDEwMn0sICJ1cCI6IHsieCI6IDAsICJ5Ijog
# MSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MTM2ODI2OTk2MjE3NzcyMywgInki
# OiAtMC40OTEzMjM5NTEzNjg2ODU1NiwgInoiOiAtMC43NjY0NjQyMTg4OTQyMDI2fSwgIm5vdyI6
# IDIyNjIzLCAicG9zaXRpb24iOiB7IngiOiAwLjAzMDAwMzExMTgwOTQ5MjExLCAieSI6IDAuMDMw
# MjgyMTU0Njc5Mjk4NCwgInoiOiAwLjA4MjAxMzUxNzYxODE3OTMyfSwgInVwIjogeyJ4IjogMCwg
# InkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQwNzM2Nzc0MTgxMzAxMDMs
# ICJ5IjogLTAuNTA0NDY3OTY0NDAyMzU1MywgInoiOiAtMC43NjEyOTA3NDMyOTE4ODYyfSwgIm5v
# dyI6IDIyNjU1LCAicG9zaXRpb24iOiB7IngiOiAwLjAzMzg0MjU1OTkwMzg2MDA5LCAieSI6IDAu
# MDI4NDE2MDI2MzgzNjM4MzgyLCAieiI6IDAuMDc2ODg0NjcyMDQ1NzA3N30sICJ1cCI6IHsieCI6
# IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MDUzMDcxNTMxMTU5
# MDcwNCwgInkiOiAtMC41MTQ2MTg5MzM2MTk1MTE5LCAieiI6IC0wLjc1NTU3NDkyMzM0ODcwMDh9
# LCAibm93IjogMjI2OTEsICJwb3NpdGlvbiI6IHsieCI6IDAuMDM3MTg3NTQ2NDkxNjIyOTI1LCAi
# eSI6IDAuMDI1OTEyMzMzMjc5ODQ4MSwgInoiOiAwLjA3MTExNDEwNzk2NjQyMzAzfSwgInVwIjog
# eyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQwMDc1NjQ5
# MDQwMDA1LCAieSI6IC0wLjUyNTgzNzAyNDEzNzEzMzYsICJ6IjogLTAuNzUwMjU5NzI3OTkzNDcx
# Nn0sICJub3ciOiAyMjcyNSwgInBvc2l0aW9uIjogeyJ4IjogMC4wNDA0NDMzMzEwMDMxODkwOSwg
# InkiOiAwLjAyMzcyNDU0MTA2ODA3NzA4NywgInoiOiAwLjA2NTYzMjc1MzA3NDE2OTE2fSwgInVw
# IjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQwMDA0
# OTA1NDI1MzU3NDcsICJ5IjogLTAuNTM2MTYzNjI0MTU1ODczNSwgInoiOiAtMC43NDMyOTYyNTQ3
# NDgzMDY2fSwgIm5vdyI6IDIyNzU3LCAicG9zaXRpb24iOiB7IngiOiAwLjA0Mzg1OTE5MTIzODg4
# MDE2LCAieSI6IDAuMDIxNDEyODE5NjIzOTQ3MTQ0LCAieiI6IDAuMDYwMDU5NDgwMzY5MDkxMDM0
# fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAw
# LjM5ODE0NTIzOTQyMTc1NjQsICJ5IjogLTAuNTQ5NzI4MDU1MDY1MTQxNiwgInoiOiAtMC43MzQz
# NTY0NzU5NzA2ODg5fSwgIm5vdyI6IDIyNzkxLCAicG9zaXRpb24iOiB7IngiOiAwLjA0NjUyMDE1
# MTE5NzkxMDMxLCAieSI6IDAuMDE5NTQ3MzkzNTQ1NTA4Mzg1LCAieiI6IDAuMDU0NjQ0NTA2NDI0
# NjY1NDV9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsi
# eCI6IDAuMzk1ODI3MDU1NTUxODU0MTYsICJ5IjogLTAuNTU5NTc4NDg4MjU4MzI2NywgInoiOiAt
# MC43MjgxNDM0MzIwMDQ3NjMxfSwgIm5vdyI6IDIyODI2LCAicG9zaXRpb24iOiB7IngiOiAwLjA0
# OTM0NzIwNjk1MDE4NzY4LCAieSI6IDAuMDE3NDk4NzY3MDAzNDE3MDE1LCAieiI6IDAuMDQ5MjA0
# MzYwNjkzNjkzMTZ9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlv
# biI6IHsieCI6IDAuNDAyODU3NzMyNTQxNDM2MTQsICJ5IjogLTAuNTYyNTEzNDk5MjUyNTA3OCwg
# InoiOiAtMC43MjIwMDAxNDU3Njg4NzE1fSwgIm5vdyI6IDIyODU3LCAicG9zaXRpb24iOiB7Ingi
# OiAwLjA1MTgyNDUwNjM3MjIxMzM2NCwgInkiOiAwLjAxNjA0NDg2ODE1NjMxMzg5NiwgInoiOiAw
# LjA0NDA2NzUwOTQ3MjM3MDE1fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJk
# aXJlY3Rpb24iOiB7IngiOiAwLjQxMTM4Njc3ODIzMzYyNDQsICJ5IjogLTAuNTYyNzI2NjMyMzA4
# ODQzNywgInoiOiAtMC43MTcwMDc0MzA5MTMzMTA4fSwgIm5vdyI6IDIyODg2LCAicG9zaXRpb24i
# OiB7IngiOiAwLjA1MzcwOTIzODc2NzYyMzksICJ5IjogMC4wMTUzODY3MTkyNTY2Mzk0OCwgInoi
# OiAwLjA0MDQ3OTc0MTk5MDU2NjI1NH0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0s
# IHsiZGlyZWN0aW9uIjogeyJ4IjogMC40MTM1MDYyNTAxNDY1MjA2LCAieSI6IC0wLjU2NDQ3NTg1
# NjE4OTU3MzEsICJ6IjogLTAuNzE0NDA4NTU4Nzg3NDg1MX0sICJub3ciOiAyMjkyNSwgInBvc2l0
# aW9uIjogeyJ4IjogMC4wNTYxMTE1NTE4MjEyMzE4NCwgInkiOiAwLjAxNDQ1OTgyNjk4MzUxMTQ0
# OCwgInoiOiAwLjAzNTkzNDc0MjU0MDEyMTA4fSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6
# IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQxMjkyNjM4NTk2MjEwOTgsICJ5IjogLTAuNTY3
# NzYzNjIwMDg0OTc2NCwgInoiOiAtMC43MTIxMzUwMDkzMDk1MjIzfSwgIm5vdyI6IDIyOTU5LCAi
# cG9zaXRpb24iOiB7IngiOiAwLjA1ODgxMzUyNzIyNjQ0ODA2LCAieSI6IDAuMDEzNTEwODUxMTg5
# NDk0MTMzLCAieiI6IDAuMDMxNDA5NzgxNDI2MTkxMzN9LCAidXAiOiB7IngiOiAwLCAieSI6IDEs
# ICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDExMzE1ODY3NDQzMDYzOCwgInkiOiAt
# MC41NzEyMzg2NDM0OTEyNjMyLCAieiI6IC0wLjcxMDI4NTYyNTIwNDI3MDR9LCAibm93IjogMjMw
# MDAsICJwb3NpdGlvbiI6IHsieCI6IDAuMDU4OTA3MTEzOTY5MzI2MDIsICJ5IjogMC4wMTM4Nzk2
# NDE4OTA1MjU4MTgsICJ6IjogMC4wMjk3NjE2MjczMTY0NzQ5MTV9LCAidXAiOiB7IngiOiAwLCAi
# eSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE0MzM5NDIyOTAyNjI5NTQs
# ICJ5IjogLTAuNTc0MTU4NDgwMzU4ODQxOCwgInoiOiAtMC43MDYxNjIwNzkxNzIxNTUzfSwgIm5v
# dyI6IDIzMDMwLCAicG9zaXRpb24iOiB7IngiOiAwLjA2MTQwNDA0OTM5NjUxNDg5LCAieSI6IDAu
# MDEzMTA5Mjk2NTYwMjg3NDc2LCAieiI6IDAuMDI1Nzk4NTQ0Mjg3NjgxNTh9LCAidXAiOiB7Ingi
# OiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAuNDE2NzAxNDQwMDMx
# NTA3NSwgInkiOiAtMC41NzcxOTIwMjg1OTAxMDEzLCAieiI6IC0wLjcwMjI4ODU5NTk1NDQ3Nzh9
# LCAibm93IjogMjMwNTcsICJwb3NpdGlvbiI6IHsieCI6IDAuMDYxNDg2MjIxODQ5OTE4MzY1LCAi
# eSI6IDAuMDEzNzgyMDcwOTQ5NjczNjUzLCAieiI6IDAuMDI0MzU5NDE0MzUzOTY2NzEzfSwgInVw
# IjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQxNjE3
# MzQyOTU4NzAyMjEsICJ5IjogLTAuNTc4NDQxOTc5MjYwMDg3OCwgInoiOiAtMC43MDE1NzI5MTM2
# MjcyNjR9LCAibm93IjogMjMwOTMsICJwb3NpdGlvbiI6IHsieCI6IDAuMDYyOTg0NDk2MzU1MDU2
# NzYsICJ5IjogMC4wMTMxMTc1NTU1Mjg4NzkxNjYsICJ6IjogMC4wMjA4OTkwNTU1MjU2NjA1MTV9
# LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRpcmVjdGlvbiI6IHsieCI6IDAu
# NDE0NjEwOTA2NjUwNTUyMTcsICJ5IjogLTAuNTc3ODgwNTM3NDczMDcwMiwgInoiOiAtMC43MDI5
# NTkzNzMyODk5ODA4fSwgIm5vdyI6IDIzMTI2LCAicG9zaXRpb24iOiB7IngiOiAwLjA2NDM1MzYx
# NTA0NTU0NzQ5LCAieSI6IDAuMDEyNjI0NjMwNzA0NTIyMTMzLCAieiI6IDAuMDE3NDU5NjU3MDQz
# MjE4NjEzfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9fSwgeyJkaXJlY3Rpb24iOiB7
# IngiOiAwLjQxNjU5NTc5NzQzNzYwNTE2LCAieSI6IC0wLjU3MzcxMzQxOTM5NjczNzcsICJ6Ijog
# LTAuNzA1MTk1NjEzOTY5MjIyNH0sICJub3ciOiAyMzE2MCwgInBvc2l0aW9uIjogeyJ4IjogMC4w
# NjU3MDU0NjMyOTAyMTQ1NCwgInkiOiAwLjAxMjM0MjkyNTE4MzQ3NTAxOCwgInoiOiAwLjAxNDEz
# NzQ3MTA5NDcyNzUxNn0sICJ1cCI6IHsieCI6IDAsICJ5IjogMSwgInoiOiAwfX0sIHsiZGlyZWN0
# aW9uIjogeyJ4IjogMC40MTY3MzQ3MzQ4MTA0MjE0NSwgInkiOiAtMC41NzM4OTI1MjQwMTMyNzY0
# LCAieiI6IC0wLjcwNDk2Nzc1MjIyOTk1NzJ9LCAibm93IjogMjMxOTUsICJwb3NpdGlvbiI6IHsi
# eCI6IDAuMDY1MzkxMTgyODk5NDc1MSwgInkiOiAwLjAxMzg1MDQ0Njc5MDQ1Njc3MiwgInoiOiAw
# LjAxMzUyNDk3NzQ5MDMwNTl9LCAidXAiOiB7IngiOiAwLCAieSI6IDEsICJ6IjogMH19LCB7ImRp
# cmVjdGlvbiI6IHsieCI6IDAuNDE3NDA5OTcxMDI5MTI4NjMsICJ5IjogLTAuNTc0NjMzNTk2MDAz
# ODE3NiwgInoiOiAtMC43MDM5NjM4ODE0ODA1NjUzfSwgIm5vdyI6IDIzMjI2LCAicG9zaXRpb24i
# OiB7IngiOiAwLjA2NzIxNzgxOTM5MjY4MTEyLCAieSI6IDAuMDEzNTE3Mjc4MjQ2NTgxNTU0LCAi
# eiI6IDAuMDEwMjU1NjE4MDIwODkyMTQzfSwgInVwIjogeyJ4IjogMCwgInkiOiAxLCAieiI6IDB9
# fSwgeyJkaXJlY3Rpb24iOiB7IngiOiAwLjQxODAzNjkyMDM0MzgyMjE3LCAieSI6IC0wLjU3NDEx
# NTcwODI4MzI0MjQsICJ6IjogLTAuNzA0MDE0NDA4MDQyODIxfSwgIm5vdyI6IDIzMjU5LCAicG9z
# aXRpb24iOiB7IngiOiAwLjA2OTA0Mjc5NDQwNjQxNDAzLCAieSI6IDAuMDEzMjI1NDUxMTExNzkz
# NTE4LCAieiI6IDAuMDA2OTk4NjAyMzAwODgyMzM5NX19XQ=="""
# )
#
# print(f'{len(history) = !r}')
# print(f'{history[0] = !r}')

# %% [markdown]
# # End
